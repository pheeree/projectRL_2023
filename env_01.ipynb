# %% [markdown]
# <a href="https://colab.research.google.com/github/pheeree/projectRL_2023/blob/main/%08env_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Install GYM by OpenAI

# %%
pip install gym
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym) (0.0.8)

# %% [markdown]
# # 2. Import Library

# %%
import gym
from gym import spaces
import numpy as np
import random
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # 3. Modeling RL
# ## (1) Set Env.
#
# 배치로 부터 나온 리워드를 바탕으로 다음 환경의 리워드에 제한을 추가하는 동적 환경을 구성한고 액션에 따른 리워드를 설정함

# %%
# 동적 환경 클래스 정의
class DynamicEnv(gym.Env):
    def __init__(self):
        super(DynamicEnv, self).__init__()
        self.observation_space = spaces.Discrete(4)  # 네 개의 상태 (0, 1, 2, 3)
        self.action_space = spaces.Discrete(2)  # 두 가지 선택 (0: 현상유지, 1: 변화)
        self.stage = 0
        self.action_prob = 0.3 # 초기 '1' 선택 확률
        self.reward_scale = 1.0  # 보상 스케일 (1을 선택할 때의 보상 크기)

    def step(self, action):
        reward = 0
        done = False

        # 마지막 스테이지 포함 모든 스테이지에서 같은 보상 체계 적용
        if action == 1:
            reward = (10 - self.reward_scale) if random.random() < self.action_prob else (-10 + self.reward_scale)
        else:
            reward = (5 - self.reward_scale) if random.random() < (1 - self.action_prob) else (-5 + self.reward_scale)

        self.stage += 1

        if self.stage == 3:  # 스테이지 3에서는 항상 종료
            done = True

        return self.stage, reward, done, {}

    def reset(self):
        self.stage = 0
        return self.stage

    def update_reward_scale(self, total_reward_batch):
        # 리워드 스케일을 이전 배치의 총 보상에 따라 조정
        self.reward_scale = np.sqrt(abs(total_reward_batch / batch_size)) # 적절한 범위 내에서 조정

# %% [markdown]
# ## (2) Set Agent

# %%
# 에이전트 클래스 정의
class ReinforcementAgent:
    def __init__(self, action_space, state_space, learning_rate=0.1, gamma=0.9, epsilon=0.1):
        self.action_space = action_space
        self.state_space = state_space
        self.learning_rate = learning_rate
        self.gamma = gamma
        self.epsilon = epsilon
        self.Q = np.zeros((state_space, action_space))
        self.recent_reward = 0

    def choose_action(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.randint(0, self.action_space - 1)
        else:
            if self.recent_reward > 0:
                # 양수 보상일 때 랜덤 확률로 액션 0 선택 강화
                return 0 if random.uniform(0.4, 1) > 0.4 else 1
            elif self.recent_reward < 0:
                # 음수 보상일 때 랜덤 확률로 액션 1 선택 강화
                return 1 if random.uniform(0.4, 1) > 0.4 else 0
            else:
                return random.randint(0, self.action_space - 1)

    def learn_sarsa(self, state, action, reward, next_state, next_action):
        predict = self.Q[state, action]
        target = reward + self.gamma * self.Q[next_state, next_action]
        self.Q[state, action] += self.learning_rate * (target - predict)

    def learn_q_learning(self, state, action, reward, next_state):
        predict = self.Q[state, action]
        target = reward + self.gamma * np.max(self.Q[next_state, :])
        self.Q[state, action] += self.learning_rate * (target - predict)

# %% [markdown]
# ## (3) 학습
# ### a. SARSA

# %%
# 환경 및 에이전트 초기화
env = DynamicEnv()
agent = ReinforcementAgent(env.action_space.n, env.observation_space.n)

# 배치 학습 설정 및 실행
num_batches = 1000
batch_size = 1000

for batch in range(num_batches):
    episode_data_sarsa = []
    total_reward_batch = 0

    for episode in range(batch_size):
        state = env.reset()
        episode_reward_sarsa = 0
        episode_actions_sarsa = []
        episode_rewards_sarsa = []  # 각 스테이지별 보상을 저장하기 위한 리스트

        # SARSA 학습
        while True:
            action = agent.choose_action(state)
            episode_actions_sarsa.append(action)
            next_state, reward, done, _ = env.step(action)
            episode_rewards_sarsa.append(reward)  # 스테이지별 보상 추가
            episode_reward_sarsa += reward
            agent.recent_reward = reward
            next_action = agent.choose_action(next_state)
            agent.learn_sarsa(state, action, reward, next_state, next_action)
            state = next_state
            if done:
                break

        episode_data_sarsa.append({
            'Episode': episode + 1,
            'Stage Rewards': episode_rewards_sarsa,
            'Total Reward': episode_reward_sarsa
        })

        total_reward_batch += episode_reward_sarsa

    env.update_reward_scale(total_reward_batch)

    # 데이터 프레임 생성
    df_sarsa = pd.DataFrame(episode_data_sarsa)
    #print(f"Batch {batch + 1} SARSA Episode Data:")
    #print(df_sarsa)
    print(f"Batch {batch + 1} Total Average Reward: {total_reward_batch / batch_size}")

    # 에피소드별 총 보상을 기준으로 데이터 프레임 정렬
    df_sorted = df_sarsa.sort_values(by='Total Reward', ascending=False)

    # 상위 10% 에피소드의 평균 점수 계산
    top_10_avg_reward = df_sorted['Total Reward'].head(int(batch_size*0.1)).mean()

    #print(f"Batch {batch + 1} Top 100 Episodes Average Reward: {top_10_avg_reward}")
# Out:
# Batch 1 Total Average Reward: -3.283
# Batch 2 Total Average Reward: -3.818947580877292
# Batch 3 Total Average Reward: -2.769893787778334
# Batch 4 Total Average Reward: -2.728214989451696
# Batch 5 Total Average Reward: -3.371075374689192
# Batch 6 Total Average Reward: -2.8860162930919997
# Batch 7 Total Average Reward: -3.793959403227429
# Batch 8 Total Average Reward: -2.7868079726389414
# Batch 9 Total Average Reward: -1.9420997643195466
# Batch 10 Total Average Reward: -4.480132781771521
# Batch 11 Total Average Reward: -4.125539635572937
# Batch 12 Total Average Reward: -2.8900000000000032
# Batch 13 Total Average Reward: -2.2094000000000005
# Batch 14 Total Average Reward: -2.478640505919488
# Batch 15 Total Average Reward: -3.050189918013273
# Batch 16 Total Average Reward: -2.6237605918682374
# Batch 17 Total Average Reward: -2.5163446059035572
# Batch 18 Total Average Reward: -3.4607864699914925
# Batch 19 Total Average Reward: -3.853158540893302
# Batch 20 Total Average Reward: -2.3534428537060306
# Batch 21 Total Average Reward: -3.277045382118968
# Batch 22 Total Average Reward: -3.441558586811605
# Batch 23 Total Average Reward: -2.785317698906186
# Batch 24 Total Average Reward: -3.3998372480710897
# Batch 25 Total Average Reward: -3.0289368114482986
# Batch 26 Total Average Reward: -3.179307708837554
# Batch 27 Total Average Reward: -3.584561621613039
# Batch 28 Total Average Reward: -2.688158578782207
# Batch 29 Total Average Reward: -2.917140661270344
# Batch 30 Total Average Reward: -2.5999026279504487
# Batch 31 Total Average Reward: -2.613698112534069
# Batch 32 Total Average Reward: -2.784967581519378
# Batch 33 Total Average Reward: -3.0833376444277465
# Batch 34 Total Average Reward: -3.3885720665805468
# Batch 35 Total Average Reward: -2.980547080806058
# Batch 36 Total Average Reward: -2.6482270094319564
# Batch 37 Total Average Reward: -3.2006144308714
# Batch 38 Total Average Reward: -2.8586707833721903
# Batch 39 Total Average Reward: -2.5414456249433175
# Batch 40 Total Average Reward: -3.0926813230121293
# Batch 41 Total Average Reward: -2.9205516125605717
# Batch 42 Total Average Reward: -2.2427320630653207
# Batch 43 Total Average Reward: -2.9809660555269897
# Batch 44 Total Average Reward: -3.421516920335424
# Batch 45 Total Average Reward: -2.459973428371088
# Batch 46 Total Average Reward: -3.8066934868993725
# Batch 47 Total Average Reward: -2.922315049394648
# Batch 48 Total Average Reward: -3.4284986276339824
# Batch 49 Total Average Reward: -3.413341660526127
# Batch 50 Total Average Reward: -2.977170277380211
# Batch 51 Total Average Reward: -2.354093889138431
# Batch 52 Total Average Reward: -3.3704511092792484
# Batch 53 Total Average Reward: -2.5722596415166428
# Batch 54 Total Average Reward: -2.7348142874814245
# Batch 55 Total Average Reward: -3.046925452157398
# Batch 56 Total Average Reward: -3.813168331415886
# Batch 57 Total Average Reward: -3.3968906578553795
# Batch 58 Total Average Reward: -2.3922262605393976
# Batch 59 Total Average Reward: -2.1842014105904406
# Batch 60 Total Average Reward: -3.4010769865573867
# Batch 61 Total Average Reward: -2.9587680362927706
# Batch 62 Total Average Reward: -3.3974348647695733
# Batch 63 Total Average Reward: -3.082627147238937
# Batch 64 Total Average Reward: -2.300384144179938
# Batch 65 Total Average Reward: -3.5552964233249673
# Batch 66 Total Average Reward: -3.5299629769694296
# Batch 67 Total Average Reward: -2.833910421943963
# Batch 68 Total Average Reward: -2.8944973329441894
# Batch 69 Total Average Reward: -3.5948677769220576
# Batch 70 Total Average Reward: -3.3950312080562552
# Batch 71 Total Average Reward: -2.5697751278598933
# Batch 72 Total Average Reward: -3.329198580080614
# Batch 73 Total Average Reward: -3.0677015633673212
# Batch 74 Total Average Reward: -3.1539821736346267
# Batch 75 Total Average Reward: -3.024344327414427
# Batch 76 Total Average Reward: -3.255871816851091
# Batch 77 Total Average Reward: -3.9135130615199247
# Batch 78 Total Average Reward: -3.3487826360518023
# Batch 79 Total Average Reward: -2.6826801282677337
# Batch 80 Total Average Reward: -3.168275777848554
# Batch 81 Total Average Reward: -1.8424330909474536
# Batch 82 Total Average Reward: -2.822576701189436
# Batch 83 Total Average Reward: -2.15864778314486
# Batch 84 Total Average Reward: -3.6948304959077714
# Batch 85 Total Average Reward: -3.4696683487273914
# Batch 86 Total Average Reward: -2.810684410635229
# Batch 87 Total Average Reward: -2.5444751126224334
# Batch 88 Total Average Reward: -2.9326680246714725
# Batch 89 Total Average Reward: -2.996850013751426
# Batch 90 Total Average Reward: -3.1980560902215878
# Batch 91 Total Average Reward: -2.837335011051698
# Batch 92 Total Average Reward: -3.5719826299917314
# Batch 93 Total Average Reward: -2.7872978264634742
# Batch 94 Total Average Reward: -2.906763688105968
# Batch 95 Total Average Reward: -2.676147701016722
# Batch 96 Total Average Reward: -3.270118174204855
# Batch 97 Total Average Reward: -3.220115885196919
# Batch 98 Total Average Reward: -3.736596588653622
# Batch 99 Total Average Reward: -3.340410998147011
# Batch 100 Total Average Reward: -2.9002089408353795
# Batch 101 Total Average Reward: -2.9186239998610275
# Batch 102 Total Average Reward: -3.1887480575990073
# Batch 103 Total Average Reward: -3.3271431492392036
# Batch 104 Total Average Reward: -2.7543137411160385
# Batch 105 Total Average Reward: -3.3905078980269194
# Batch 106 Total Average Reward: -3.145269334520337
# Batch 107 Total Average Reward: -3.3716677238269335
# Batch 108 Total Average Reward: -3.086948217256558
# Batch 109 Total Average Reward: -3.2406653766679425
# Batch 110 Total Average Reward: -3.6339778219163192
# Batch 111 Total Average Reward: -2.6810661637417486
# Batch 112 Total Average Reward: -3.3238326846354562
# Batch 113 Total Average Reward: -3.5203936332371284
# Batch 114 Total Average Reward: -3.0025355937289966
# Batch 115 Total Average Reward: -3.121931130463336
# Batch 116 Total Average Reward: -2.5378181011251346
# Batch 117 Total Average Reward: -2.1284691121071204
# Batch 118 Total Average Reward: -2.786671419072882
# Batch 119 Total Average Reward: -3.349808050866656
# Batch 120 Total Average Reward: -2.5251729003947245
# Batch 121 Total Average Reward: -2.678522914233781
# Batch 122 Total Average Reward: -2.2122196645885235
# Batch 123 Total Average Reward: -3.4027840990355873
# Batch 124 Total Average Reward: -2.6241264577275847
# Batch 125 Total Average Reward: -3.600967767452122
# Batch 126 Total Average Reward: -3.096866594973757
# Batch 127 Total Average Reward: -3.0518433338565556
# Batch 128 Total Average Reward: -3.239762077699404
# Batch 129 Total Average Reward: -1.9161878393036038
# Batch 130 Total Average Reward: -2.391898505729386
# Batch 131 Total Average Reward: -3.0476711808940316
# Batch 132 Total Average Reward: -3.112542419466334
# Batch 133 Total Average Reward: -2.5902689545191118
# Batch 134 Total Average Reward: -3.8582418997296766
# Batch 135 Total Average Reward: -3.700718957346812
# Batch 136 Total Average Reward: -3.441474922447012
# Batch 137 Total Average Reward: -3.5894878731067137
# Batch 138 Total Average Reward: -2.5044162089951847
# Batch 139 Total Average Reward: -3.390504791549215
# Batch 140 Total Average Reward: -3.3261067361007903
# Batch 141 Total Average Reward: -2.914590093594983
# Batch 142 Total Average Reward: -2.91865773648853
# Batch 143 Total Average Reward: -2.140760297619614
# Batch 144 Total Average Reward: -3.1204838721518513
# Batch 145 Total Average Reward: -2.490121261335491
# Batch 146 Total Average Reward: -2.158581298710892
# Batch 147 Total Average Reward: -2.7360910890935326
# Batch 148 Total Average Reward: -2.742479710152403
# Batch 149 Total Average Reward: -3.4605736569303813
# Batch 150 Total Average Reward: -2.1219519295131697
# Batch 467 Total Average Reward: -3.278196252981092
# Batch 468 Total Average Reward: -2.639498212865236
# Batch 469 Total Average Reward: -2.3722132454829
# Batch 470 Total Average Reward: -3.390623276204223
# Batch 471 Total Average Reward: -3.215297232321205
# Batch 472 Total Average Reward: -2.484208749201353
# Batch 473 Total Average Reward: -3.0296750203260694
# Batch 474 Total Average Reward: -3.717203690486081
# Batch 475 Total Average Reward: -2.9710158570194736
# Batch 476 Total Average Reward: -3.59297563111487
# Batch 477 Total Average Reward: -2.6185667596430755
# Batch 478 Total Average Reward: -2.870581616612381
# Batch 479 Total Average Reward: -2.626159721554434
# Batch 480 Total Average Reward: -2.407232581975366
# Batch 481 Total Average Reward: -3.1275877928938316
# Batch 482 Total Average Reward: -2.5667209168309033
# Batch 483 Total Average Reward: -3.2293664174429573
# Batch 484 Total Average Reward: -3.5659192696503506
# Batch 485 Total Average Reward: -2.8752138268518017
# Batch 486 Total Average Reward: -4.0560447635507195
# Batch 487 Total Average Reward: -2.9980558498134466
# Batch 488 Total Average Reward: -2.562352348305394
# Batch 489 Total Average Reward: -3.7053220963544238
# Batch 490 Total Average Reward: -2.9453514162018286
# Batch 491 Total Average Reward: -2.540052666743936
# Batch 492 Total Average Reward: -1.528438566998095
# Batch 493 Total Average Reward: -3.844335752472001
# Batch 494 Total Average Reward: -2.8698995376113303
# Batch 495 Total Average Reward: -2.8532565114612005
# Batch 496 Total Average Reward: -2.4602676328669535
# Batch 497 Total Average Reward: -3.5540256062566815
# Batch 498 Total Average Reward: -3.435902780084987
# Batch 499 Total Average Reward: -3.505930878978072
# Batch 500 Total Average Reward: -2.118393010082042
# Batch 501 Total Average Reward: -2.789109400612736
# Batch 502 Total Average Reward: -3.2783197492255294
# Batch 503 Total Average Reward: -3.193272642961284
# Batch 504 Total Average Reward: -2.205158602943911
# Batch 505 Total Average Reward: -3.0243605365459354
# Batch 506 Total Average Reward: -2.6856502038578705
# Batch 507 Total Average Reward: -2.9684448185942904
# Batch 508 Total Average Reward: -1.8461376711361177
# Batch 509 Total Average Reward: -2.6997839655034674
# Batch 510 Total Average Reward: -3.289841476224216
# Batch 511 Total Average Reward: -2.986862079842981
# Batch 512 Total Average Reward: -2.831847621660581
# Batch 513 Total Average Reward: -3.303268762227753
# Batch 514 Total Average Reward: -3.0627604950256306
# Batch 515 Total Average Reward: -3.1920002977022675
# Batch 516 Total Average Reward: -3.196401490058659
# Batch 517 Total Average Reward: -2.687270897098002
# Batch 518 Total Average Reward: -3.0551642614768633
# Batch 519 Total Average Reward: -3.8333019941954625
# Batch 520 Total Average Reward: -4.035475337733443
# Batch 521 Total Average Reward: -3.7791150742904427
# Batch 522 Total Average Reward: -3.2505843444566045
# Batch 523 Total Average Reward: -2.8800000000000097
# Batch 524 Total Average Reward: -3.0262412121521316
# Batch 525 Total Average Reward: -3.4123520210079663
# Batch 526 Total Average Reward: -3.2039164683987322
# Batch 527 Total Average Reward: -3.3268633835919377
# Batch 528 Total Average Reward: -3.0482396912901217
# Batch 529 Total Average Reward: -2.752296043600069
# Batch 971 Total Average Reward: -2.637279561033919
# Batch 972 Total Average Reward: -2.201628496335581
# Batch 973 Total Average Reward: -3.784750835318066
# Batch 974 Total Average Reward: -3.033327338346742
# Batch 975 Total Average Reward: -3.404434459517485
# Batch 976 Total Average Reward: -2.828690221922618
# Batch 977 Total Average Reward: -2.5558210365891396
# Batch 978 Total Average Reward: -2.6653425157841015
# Batch 979 Total Average Reward: -2.0760095540104544
# Batch 980 Total Average Reward: -2.8985685116517708
# Batch 981 Total Average Reward: -3.406469049166373
# Batch 982 Total Average Reward: -2.923556159896351
# Batch 983 Total Average Reward: -2.8691968195006305
# Batch 984 Total Average Reward: -3.977368482046649
# Batch 985 Total Average Reward: -2.8580339954306546
# Batch 986 Total Average Reward: -3.3316599536183538
# Batch 987 Total Average Reward: -2.3900709809915326
# Batch 988 Total Average Reward: -3.3227007279951635
# Batch 989 Total Average Reward: -3.394795582357342
# Batch 990 Total Average Reward: -3.28341008105678
# Batch 991 Total Average Reward: -3.0072480729367816
# Batch 992 Total Average Reward: -3.1533805947902738
# Batch 993 Total Average Reward: -2.9328968957830615
# Batch 994 Total Average Reward: -3.1840960654343338
# Batch 995 Total Average Reward: -2.522752284811067
# Batch 996 Total Average Reward: -2.820470095370192
# Batch 997 Total Average Reward: -3.3954928516630547
# Batch 998 Total Average Reward: -2.525324749279978
# Batch 999 Total Average Reward: -3.563374279679298
# Batch 1000 Total Average Reward: -2.5986674981198465

# %% [markdown]
# ### b. Q-Learning

# %%
# 환경 및 에이전트 초기화
env = DynamicEnv()
agent = ReinforcementAgent(env.action_space.n, env.observation_space.n)

# 배치 학습 설정
num_batches = 100
batch_size = 1000

for batch in range(num_batches):
    episode_data_q_learning = []
    total_reward_batch = 0

    for episode in range(batch_size):
        state = env.reset()
        episode_reward_q_learning = 0
        episode_actions_q_learning = []
        episode_rewards_q_learning = []  # 각 스테이지별 보상을 저장하기 위한 리스트

        # Q-Learning 학습
        while True:
            action = agent.choose_action(state)
            episode_actions_q_learning.append(action)
            next_state, reward, done, _ = env.step(action)
            episode_rewards_q_learning.append(reward)  # 스테이지별 보상 추가
            episode_reward_q_learning += reward
            agent.recent_reward = reward
            agent.learn_q_learning(state, action, reward, next_state)
            state = next_state
            if done:
                break

        episode_data_q_learning.append({
            'Episode': episode + 1,
            'Actions': episode_rewards_q_learning,
            'Total Reward': episode_reward_q_learning
        })

        total_reward_batch += episode_reward_q_learning

    env.update_reward_scale(total_reward_batch)

    # Q-Learning 결과 처리
    df_q_learning = pd.DataFrame(episode_data_q_learning)
    batch_avg_reward_q_learning = df_q_learning['Total Reward'].mean()
    #print(f"Batch {batch + 1} Q-Learning Episode Data")
    #print(df_q_learning)
    print(f"Batch {batch + 1} Q-Learning Episode Data : ", total_reward_batch / batch_size)

    # 에피소드별 총 보상을 기준으로 데이터 프레임 정렬
    df_sorted_Q = df_q_learning.sort_values(by='Total Reward', ascending=False)

    # 상위 10% 에피소드의 평균 점수 계산
    top_10_avg_reward_Q = df_sorted_Q['Total Reward'].head(int(batch_size*0.1)).mean()

    #print(f"Batch {batch + 1} Top 100 Episodes Average Reward: {top_10_avg_reward_Q}")
# Out:
# Batch 1 Q-Learning Episode Data :  -3.118
# Batch 2 Q-Learning Episode Data :  -3.2381791309124153
# Batch 3 Q-Learning Episode Data :  -3.755268798055177
# Batch 4 Q-Learning Episode Data :  -3.3434915617583236
# Batch 5 Q-Learning Episode Data :  -2.821570433750548
# Batch 6 Q-Learning Episode Data :  -2.8338306173112593
# Batch 7 Q-Learning Episode Data :  -3.142664058722717
# Batch 8 Q-Learning Episode Data :  -3.337816684726653
# Batch 9 Q-Learning Episode Data :  -3.650379442642696
# Batch 10 Q-Learning Episode Data :  -3.099185396065999
# Batch 11 Q-Learning Episode Data :  -2.64858521898369
# Batch 12 Q-Learning Episode Data :  -2.6608038440113377
# Batch 13 Q-Learning Episode Data :  -3.2834401470696006
# Batch 14 Q-Learning Episode Data :  -3.7975568163455056
# Batch 15 Q-Learning Episode Data :  -2.6825137831275763
# Batch 16 Q-Learning Episode Data :  -3.481216185685911
# Batch 17 Q-Learning Episode Data :  -2.63411696839574
# Batch 18 Q-Learning Episode Data :  -2.7752620222395885
# Batch 19 Q-Learning Episode Data :  -2.6099320592139628
# Batch 20 Q-Learning Episode Data :  -2.745541625126878
# Batch 21 Q-Learning Episode Data :  -2.9833139351985998
# Batch 22 Q-Learning Episode Data :  -3.1254554552196803
# Batch 23 Q-Learning Episode Data :  -2.771930580064057
# Batch 24 Q-Learning Episode Data :  -2.7882245181619507
# Batch 25 Q-Learning Episode Data :  -2.8284711008979797
# Batch 26 Q-Learning Episode Data :  -2.8681819409535523
# Batch 27 Q-Learning Episode Data :  -3.2533857540133626
# Batch 28 Q-Learning Episode Data :  -3.280066280429953
# Batch 29 Q-Learning Episode Data :  -3.1501559028245336
# Batch 30 Q-Learning Episode Data :  -2.205083614023917
# Batch 31 Q-Learning Episode Data :  -3.2185718090078104
# Batch 32 Q-Learning Episode Data :  -3.355065047661412
# Batch 33 Q-Learning Episode Data :  -2.7272772446010323
# Batch 34 Q-Learning Episode Data :  -2.669360774645866
# Batch 35 Q-Learning Episode Data :  -2.562085078389161
# Batch 36 Q-Learning Episode Data :  -2.6586299669011977
# Batch 37 Q-Learning Episode Data :  -2.380876079327109
# Batch 38 Q-Learning Episode Data :  -3.208709736753886
# Batch 39 Q-Learning Episode Data :  -3.0644083178096815
# Batch 40 Q-Learning Episode Data :  -2.656509812677489
# Batch 41 Q-Learning Episode Data :  -2.7834549728621916
# Batch 42 Q-Learning Episode Data :  -3.634857007708142
# Batch 43 Q-Learning Episode Data :  -2.3874186950068603
# Batch 44 Q-Learning Episode Data :  -2.9428122932744185
# Batch 45 Q-Learning Episode Data :  -2.943032955748394
# Batch 46 Q-Learning Episode Data :  -2.6145005671498303
# Batch 47 Q-Learning Episode Data :  -3.11972563148264
# Batch 48 Q-Learning Episode Data :  -3.4765796082606957
# Batch 49 Q-Learning Episode Data :  -3.262959411742762
# Batch 50 Q-Learning Episode Data :  -3.692397839156069
# Batch 51 Q-Learning Episode Data :  -2.2748423754570393
# Batch 52 Q-Learning Episode Data :  -2.407974451076171
# Batch 53 Q-Learning Episode Data :  -2.9974141195768746
# Batch 54 Q-Learning Episode Data :  -3.296883491622653
# Batch 55 Q-Learning Episode Data :  -2.3387822596116274
# Batch 56 Q-Learning Episode Data :  -2.389872161595507
# Batch 57 Q-Learning Episode Data :  -2.1581431673357465
# Batch 58 Q-Learning Episode Data :  -3.4506706518623056
# Batch 59 Q-Learning Episode Data :  -2.3069053971945053
# Batch 60 Q-Learning Episode Data :  -2.9803770004917824
# Batch 61 Q-Learning Episode Data :  -3.6117599958080855
# Batch 62 Q-Learning Episode Data :  -2.836199073799291
# Batch 63 Q-Learning Episode Data :  -2.4750419822492713
# Batch 64 Q-Learning Episode Data :  -2.479565222742536
# Batch 65 Q-Learning Episode Data :  -2.9996425975903547
# Batch 66 Q-Learning Episode Data :  -4.392765825334909
# Batch 67 Q-Learning Episode Data :  -3.6257668200609077
# Batch 68 Q-Learning Episode Data :  -2.37518130712207
# Batch 69 Q-Learning Episode Data :  -2.9308232464683517
# Batch 70 Q-Learning Episode Data :  -2.9528803526716585
# Batch 71 Q-Learning Episode Data :  -2.7478046834491856
# Batch 72 Q-Learning Episode Data :  -2.4927202238121864
# Batch 73 Q-Learning Episode Data :  -3.3713238739213782
# Batch 74 Q-Learning Episode Data :  -3.585766212345058
# Batch 75 Q-Learning Episode Data :  -2.4769356426671525
# Batch 76 Q-Learning Episode Data :  -3.647798419469882
# Batch 77 Q-Learning Episode Data :  -3.2538825263812616
# Batch 78 Q-Learning Episode Data :  -2.8480998444796377
# Batch 79 Q-Learning Episode Data :  -3.4442452685098086
# Batch 80 Q-Learning Episode Data :  -3.7551785088511846
# Batch 81 Q-Learning Episode Data :  -2.856269697823051
# Batch 82 Q-Learning Episode Data :  -3.525854678194663
# Batch 83 Q-Learning Episode Data :  -2.875065422383909
# Batch 84 Q-Learning Episode Data :  -2.2534722145216093
# Batch 85 Q-Learning Episode Data :  -3.185946779901815
# Batch 86 Q-Learning Episode Data :  -4.080155275162386
# Batch 87 Q-Learning Episode Data :  -2.5723558808073035
# Batch 88 Q-Learning Episode Data :  -3.2168843030526713
# Batch 89 Q-Learning Episode Data :  -2.9116327544636142
# Batch 90 Q-Learning Episode Data :  -2.279523981238842
# Batch 91 Q-Learning Episode Data :  -2.5284119886370515
# Batch 92 Q-Learning Episode Data :  -3.176396075735697
# Batch 93 Q-Learning Episode Data :  -2.40317589276354
# Batch 94 Q-Learning Episode Data :  -3.185
# Batch 95 Q-Learning Episode Data :  -3.9266083389412323
# Batch 96 Q-Learning Episode Data :  -3.0668894028530405
# Batch 97 Q-Learning Episode Data :  -2.3801002932839896
# Batch 98 Q-Learning Episode Data :  -3.8932705128284653
# Batch 99 Q-Learning Episode Data :  -2.8192149021915944
# Batch 100 Q-Learning Episode Data :  -2.924851378560417

# %% [markdown]
# ### c. tables

# %%
df_sarsa.to_csv('df_sarsa_env01.csv', index=False)
df_q_learning.to_csv('df_q_learning_env01.csv', index=False)
