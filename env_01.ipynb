# %% [markdown]
# <a href="https://colab.research.google.com/github/pheeree/projectRL_2023/blob/main/%08env_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Install GYM by OpenAI

# %%
pip install gym
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym) (0.0.8)

# %% [markdown]
# # 2. Import Library

# %%
import gym
from gym import spaces
import numpy as np
import random
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # 3. Modeling RL
# ## (1) Set Env.
#
# 배치로 부터 나온 리워드를 바탕으로 다음 환경의 리워드에 제한을 추가하는 동적 환경을 구성한고 액션에 따른 리워드를 설정함

# %%
# 동적 환경 클래스 정의 - 2
class DynamicEnv(gym.Env):
    def __init__(self):
        super(DynamicEnv, self).__init__()
        self.observation_space = spaces.Discrete(4)  # 네 개의 상태 (0, 1, 2, 3)
        self.action_space = spaces.Discrete(2)  # 두 가지 선택 (0: 현상유지, 1: 변화)
        self.stage = 0
        self.action_prob = 0.3 # 초기 '1' 선택 확률
        self.reward_scale = 1.0  # 보상 스케일 (1을 선택할 때의 보상 크기)

    def step(self, action):
        reward = 0
        done = False

        # 마지막 스테이지 포함 모든 스테이지에서 같은 보상 체계 적용
        if action == 1:
            reward = (10 / self.reward_scale) if random.random() < self.action_prob else (-10 + self.reward_scale)
        else:
            reward = (5 / self.reward_scale) if random.random() < (1 - self.action_prob) else (-5 + self.reward_scale)

        self.stage += 1

        if self.stage == 3:  # 스테이지 3에서는 항상 종료
            done = True

        return self.stage, reward, done, {}

    def reset(self):
        self.stage = 0
        return self.stage

    def update_reward_scale(self, total_reward_batch):
        # 리워드 스케일을 이전 배치의 총 보상에 따라 조정
        self.reward_scale = np.sqrt(abs(total_reward_batch / batch_size)) # 적절한 범위 내에서 조정

# %% [markdown]
# ## (2) Set Agent

# %%
# 에이전트 클래스 정의
class ReinforcementAgent:
    def __init__(self, action_space, state_space, learning_rate=0.1, gamma=0.9, epsilon=0.1):
        self.action_space = action_space
        self.state_space = state_space
        self.learning_rate = learning_rate
        self.gamma = gamma
        self.epsilon = epsilon
        self.Q = np.zeros((state_space, action_space))
        self.recent_reward = 0

    def choose_action(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.randint(0, self.action_space - 1)
        else:
            if self.recent_reward > 0:
                # 양수 보상일 때 랜덤 확률로 액션 0 선택 강화
                return 0 if random.uniform(0.4, 1) > 0.4 else 1
            elif self.recent_reward < 0:
                # 음수 보상일 때 랜덤 확률로 액션 1 선택 강화
                return 1 if random.uniform(0.4, 1) > 0.4 else 0
            else:
                return random.randint(0, self.action_space - 1)

    def learn_sarsa(self, state, action, reward, next_state, next_action):
        predict = self.Q[state, action]
        target = reward + self.gamma * self.Q[next_state, next_action]
        self.Q[state, action] += self.learning_rate * (target - predict)

    def learn_q_learning(self, state, action, reward, next_state):
        predict = self.Q[state, action]
        target = reward + self.gamma * np.max(self.Q[next_state, :])
        self.Q[state, action] += self.learning_rate * (target - predict)

# %% [markdown]
# ## (3) 학습
# ### a. SARSA

# %%
# 환경 및 에이전트 초기화
env = DynamicEnv()
agent = ReinforcementAgent(env.action_space.n, env.observation_space.n)

# 배치 학습 설정 및 실행
num_batches = 1000
batch_size = 1000

for batch in range(num_batches):
    episode_data_sarsa = []
    total_reward_batch = 0

    for episode in range(batch_size):
        state = env.reset()
        episode_reward_sarsa = 0
        episode_actions_sarsa = []
        episode_rewards_sarsa = []  # 각 스테이지별 보상을 저장하기 위한 리스트

        # SARSA 학습
        while True:
            action = agent.choose_action(state)
            episode_actions_sarsa.append(action)
            next_state, reward, done, _ = env.step(action)
            episode_rewards_sarsa.append(reward)  # 스테이지별 보상 추가
            episode_reward_sarsa += reward
            agent.recent_reward = reward
            next_action = agent.choose_action(next_state)
            agent.learn_sarsa(state, action, reward, next_state, next_action)
            state = next_state
            if done:
                break

        episode_data_sarsa.append({
            'Episode': episode + 1,
            'Stage Rewards': episode_rewards_sarsa,
            'Total Reward': episode_reward_sarsa
        })

        total_reward_batch += episode_reward_sarsa

    env.update_reward_scale(total_reward_batch)

    # 데이터 프레임 생성
    df_sarsa = pd.DataFrame(episode_data_sarsa)
    #print(f"Batch {batch + 1} SARSA Episode Data:")
    #print(df_sarsa)
    print(f"Batch {batch + 1} Total Average Reward: {total_reward_batch / batch_size}")

    # 에피소드별 총 보상을 기준으로 데이터 프레임 정렬
    df_sorted = df_sarsa.sort_values(by='Total Reward', ascending=False)

    # 상위 10% 에피소드의 평균 점수 계산
    top_10_avg_reward = df_sorted['Total Reward'].head(int(batch_size*0.1)).mean()

    #print(f"Batch {batch + 1} Top 100 Episodes Average Reward: {top_10_avg_reward}")
# Out:
# Batch 1 Total Average Reward: -1.609
# Batch 2 Total Average Reward: -3.2298863788575467
# Batch 3 Total Average Reward: -4.473882050757023
# Batch 4 Total Average Reward: -5.208926240404278
# Batch 5 Total Average Reward: -5.008936390621173
# Batch 6 Total Average Reward: -6.129016789970004
# Batch 7 Total Average Reward: -5.111849069591287
# Batch 8 Total Average Reward: -4.579736399237635
# Batch 9 Total Average Reward: -4.460441524304132
# Batch 10 Total Average Reward: -4.779030962425977
# Batch 11 Total Average Reward: -4.713188932080808
# Batch 12 Total Average Reward: -5.532901882641112
# Batch 13 Total Average Reward: -4.92687587199279
# Batch 14 Total Average Reward: -4.424967707866314
# Batch 15 Total Average Reward: -4.743757377924728
# Batch 16 Total Average Reward: -4.439556761282552
# Batch 17 Total Average Reward: -4.6535706708722
# Batch 18 Total Average Reward: -5.251902935894709
# Batch 19 Total Average Reward: -5.243917105636825
# Batch 20 Total Average Reward: -5.304923321351311
# Batch 21 Total Average Reward: -5.345504658323772
# Batch 22 Total Average Reward: -5.0776548329581
# Batch 23 Total Average Reward: -5.367164450661957
# Batch 977 Total Average Reward: -5.107093978690387
# Batch 978 Total Average Reward: -5.320253452689029
# Batch 979 Total Average Reward: -4.6400713763175006
# Batch 980 Total Average Reward: -4.735231592127151
# Batch 981 Total Average Reward: -5.05150058775826
# Batch 982 Total Average Reward: -4.7583902202202815
# Batch 983 Total Average Reward: -5.300168213056563
# Batch 984 Total Average Reward: -4.329158178540017
# Batch 985 Total Average Reward: -4.194721737477761
# Batch 986 Total Average Reward: -5.082183166553816
# Batch 987 Total Average Reward: -4.771640853010016
# Batch 988 Total Average Reward: -4.936936197813446
# Batch 989 Total Average Reward: -5.196787937497295
# Batch 990 Total Average Reward: -5.642228127728217
# Batch 991 Total Average Reward: -4.75807591880394
# Batch 992 Total Average Reward: -5.146897873774047
# Batch 993 Total Average Reward: -5.3711544254915795
# Batch 994 Total Average Reward: -4.691400939259135
# Batch 995 Total Average Reward: -4.834476636186361
# Batch 996 Total Average Reward: -5.214836693931183
# Batch 997 Total Average Reward: -4.870722409160014
# Batch 998 Total Average Reward: -4.732721191471122
# Batch 999 Total Average Reward: -5.556382791104072
# Batch 1000 Total Average Reward: -4.484452326613248

# %% [markdown]
# ### b. Q-Learning

# %%
# 환경 및 에이전트 초기화
env = DynamicEnv()
agent = ReinforcementAgent(env.action_space.n, env.observation_space.n)

# 배치 학습 설정
num_batches = 1000
batch_size = 1000

for batch in range(num_batches):
    episode_data_q_learning = []
    total_reward_batch = 0

    for episode in range(batch_size):
        state = env.reset()
        episode_reward_q_learning = 0
        episode_actions_q_learning = []
        episode_rewards_q_learning = []  # 각 스테이지별 보상을 저장하기 위한 리스트

        # Q-Learning 학습
        while True:
            action = agent.choose_action(state)
            episode_actions_q_learning.append(action)
            next_state, reward, done, _ = env.step(action)
            episode_rewards_q_learning.append(reward)  # 스테이지별 보상 추가
            episode_reward_q_learning += reward
            agent.recent_reward = reward
            agent.learn_q_learning(state, action, reward, next_state)
            state = next_state
            if done:
                break

        episode_data_q_learning.append({
            'Episode': episode + 1,
            'Stage Rewards': episode_rewards_q_learning,
            'Total Reward': episode_reward_q_learning
        })

        total_reward_batch += episode_reward_q_learning

    env.update_reward_scale(total_reward_batch)

    # Q-Learning 결과 처리
    df_q_learning = pd.DataFrame(episode_data_q_learning)
    batch_avg_reward_q_learning = df_q_learning['Total Reward'].mean()
    #print(f"Batch {batch + 1} Q-Learning Episode Data")
    #print(df_q_learning)
    print(f"Batch {batch + 1} Q-Learning Episode Data : ", total_reward_batch / batch_size)

    # 에피소드별 총 보상을 기준으로 데이터 프레임 정렬
    df_sorted_Q = df_q_learning.sort_values(by='Total Reward', ascending=False)

    # 상위 10% 에피소드의 평균 점수 계산
    top_10_avg_reward_Q = df_sorted_Q['Total Reward'].head(int(batch_size*0.1)).mean()

    #print(f"Batch {batch + 1} Top 100 Episodes Average Reward: {top_10_avg_reward_Q}")
# Out:
# Batch 1 Q-Learning Episode Data :  -2.667
# Batch 2 Q-Learning Episode Data :  -5.175108674318449
# Batch 3 Q-Learning Episode Data :  -5.002784418893757
# Batch 4 Q-Learning Episode Data :  -4.860209606985793
# Batch 5 Q-Learning Episode Data :  -4.7636010521059635
# Batch 6 Q-Learning Episode Data :  -4.572201294601005
# Batch 7 Q-Learning Episode Data :  -4.999481456412366
# Batch 8 Q-Learning Episode Data :  -5.07395911172904
# Batch 9 Q-Learning Episode Data :  -4.460583859765016
# Batch 10 Q-Learning Episode Data :  -5.158054332489249
# Batch 11 Q-Learning Episode Data :  -5.149385126607728
# Batch 12 Q-Learning Episode Data :  -4.637382136591275
# Batch 13 Q-Learning Episode Data :  -4.614391372119333
# Batch 14 Q-Learning Episode Data :  -4.331656787985188
# Batch 15 Q-Learning Episode Data :  -4.74948675841087
# Batch 16 Q-Learning Episode Data :  -4.393893270981215
# Batch 17 Q-Learning Episode Data :  -4.411235969695822
# Batch 18 Q-Learning Episode Data :  -4.4404473011781604
# Batch 19 Q-Learning Episode Data :  -5.2336497829824715
# Batch 20 Q-Learning Episode Data :  -5.066085866815792
# Batch 21 Q-Learning Episode Data :  -4.949461790893184
# Batch 22 Q-Learning Episode Data :  -5.164044065735679
# Batch 23 Q-Learning Episode Data :  -5.437457211747629
# Batch 24 Q-Learning Episode Data :  -5.397400459559432
# Batch 25 Q-Learning Episode Data :  -5.1489821674047445
# Batch 26 Q-Learning Episode Data :  -5.7624052200528855
# Batch 27 Q-Learning Episode Data :  -4.877102738111027
# Batch 28 Q-Learning Episode Data :  -4.741943948879555
# Batch 29 Q-Learning Episode Data :  -4.7437173385855
# Batch 30 Q-Learning Episode Data :  -5.12738939203726
# Batch 31 Q-Learning Episode Data :  -5.061368194142703
# Batch 32 Q-Learning Episode Data :  -6.113087933396381
# Batch 33 Q-Learning Episode Data :  -4.428602558847856
# Batch 34 Q-Learning Episode Data :  -5.1265151105562055
# Batch 35 Q-Learning Episode Data :  -4.7045606942071405
# Batch 36 Q-Learning Episode Data :  -4.919791269638243
# Batch 37 Q-Learning Episode Data :  -4.858039424455352
# Batch 38 Q-Learning Episode Data :  -5.450641728264242
# Batch 39 Q-Learning Episode Data :  -4.609551263959426
# Batch 40 Q-Learning Episode Data :  -5.22059717627727
# Batch 41 Q-Learning Episode Data :  -4.6128619149069605
# Batch 42 Q-Learning Episode Data :  -4.869991545475355
# Batch 43 Q-Learning Episode Data :  -5.725413970851998
# Batch 44 Q-Learning Episode Data :  -5.663096915432305
# Batch 45 Q-Learning Episode Data :  -4.416909274579914
# Batch 46 Q-Learning Episode Data :  -4.690320813096575
# Batch 47 Q-Learning Episode Data :  -4.783978470819438
# Batch 48 Q-Learning Episode Data :  -5.190309958965768
# Batch 49 Q-Learning Episode Data :  -5.222977614932695
# Batch 50 Q-Learning Episode Data :  -5.374399396752786
# Batch 51 Q-Learning Episode Data :  -4.728391173937961
# Batch 52 Q-Learning Episode Data :  -5.375170307004901
# Batch 53 Q-Learning Episode Data :  -4.70881063174201
# Batch 54 Q-Learning Episode Data :  -4.844093613419933
# Batch 55 Q-Learning Episode Data :  -4.876894219176969
# Batch 56 Q-Learning Episode Data :  -4.86337007035721
# Batch 57 Q-Learning Episode Data :  -5.395011241111325
# Batch 58 Q-Learning Episode Data :  -5.285923237192739
# Batch 59 Q-Learning Episode Data :  -5.006008100640555
# Batch 60 Q-Learning Episode Data :  -5.4537028673455445
# Batch 61 Q-Learning Episode Data :  -5.507647440296472
# Batch 62 Q-Learning Episode Data :  -5.395551579577109
# Batch 63 Q-Learning Episode Data :  -5.5304427689813345
# Batch 64 Q-Learning Episode Data :  -5.072403843221101
# Batch 65 Q-Learning Episode Data :  -4.222596869500547
# Batch 66 Q-Learning Episode Data :  -5.350300129459697
# Batch 67 Q-Learning Episode Data :  -4.6965377764843055
# Batch 68 Q-Learning Episode Data :  -5.093145734436478
# Batch 69 Q-Learning Episode Data :  -4.254583547422158
# Batch 70 Q-Learning Episode Data :  -5.149728024973606
# Batch 71 Q-Learning Episode Data :  -5.1339492778339
# Batch 72 Q-Learning Episode Data :  -5.155647741141919
# Batch 73 Q-Learning Episode Data :  -4.9415004788292105
# Batch 74 Q-Learning Episode Data :  -5.553794384769277
# Batch 75 Q-Learning Episode Data :  -5.039326248296539
# Batch 76 Q-Learning Episode Data :  -5.826596504449466
# Batch 77 Q-Learning Episode Data :  -4.74942320840024
# Batch 78 Q-Learning Episode Data :  -5.075122705720685
# Batch 79 Q-Learning Episode Data :  -4.658509755982431
# Batch 80 Q-Learning Episode Data :  -4.423005728167849
# Batch 81 Q-Learning Episode Data :  -5.104266900538653
# Batch 82 Q-Learning Episode Data :  -5.063484610241639
# Batch 83 Q-Learning Episode Data :  -4.729276101603203
# Batch 84 Q-Learning Episode Data :  -5.336779917907957
# Batch 85 Q-Learning Episode Data :  -4.0933426734009455
# Batch 86 Q-Learning Episode Data :  -4.718484296530962
# Batch 87 Q-Learning Episode Data :  -4.746771241112914
# Batch 88 Q-Learning Episode Data :  -4.825677838776285
# Batch 89 Q-Learning Episode Data :  -4.898706953912198
# Batch 90 Q-Learning Episode Data :  -4.573423999905053
# Batch 91 Q-Learning Episode Data :  -5.334153859706018
# Batch 92 Q-Learning Episode Data :  -5.380340274460513
# Batch 93 Q-Learning Episode Data :  -5.539076809541615
# Batch 94 Q-Learning Episode Data :  -4.615530793210436
# Batch 95 Q-Learning Episode Data :  -5.003000902969117
# Batch 96 Q-Learning Episode Data :  -4.944436763319675
# Batch 97 Q-Learning Episode Data :  -4.656159341448726
# Batch 98 Q-Learning Episode Data :  -4.93859993145658
# Batch 99 Q-Learning Episode Data :  -5.33133546259211
# Batch 100 Q-Learning Episode Data :  -5.697915084807404
# Batch 101 Q-Learning Episode Data :  -4.620829317854508
# Batch 102 Q-Learning Episode Data :  -5.243407204574666
# Batch 103 Q-Learning Episode Data :  -5.164888007838816
# Batch 104 Q-Learning Episode Data :  -5.232876694110235
# Batch 105 Q-Learning Episode Data :  -5.314034357773756
# Batch 106 Q-Learning Episode Data :  -5.241327405821914
# Batch 107 Q-Learning Episode Data :  -5.194322534620399
# Batch 108 Q-Learning Episode Data :  -4.43273450733353
# Batch 109 Q-Learning Episode Data :  -4.545952547714684
# Batch 110 Q-Learning Episode Data :  -5.576267363455414
# Batch 111 Q-Learning Episode Data :  -4.561454884857914
# Batch 112 Q-Learning Episode Data :  -5.075407425041274
# Batch 113 Q-Learning Episode Data :  -5.257246180903736
# Batch 114 Q-Learning Episode Data :  -4.906719009624216
# Batch 115 Q-Learning Episode Data :  -5.363763234197123
# Batch 116 Q-Learning Episode Data :  -5.074479830227132
# Batch 117 Q-Learning Episode Data :  -5.123967392949953
# Batch 118 Q-Learning Episode Data :  -5.5362083195886225
# Batch 119 Q-Learning Episode Data :  -4.933713045746337
# Batch 120 Q-Learning Episode Data :  -5.316536194384646
# Batch 121 Q-Learning Episode Data :  -5.7514301679278415
# Batch 122 Q-Learning Episode Data :  -5.1635033705080104
# Batch 123 Q-Learning Episode Data :  -4.912770242690654
# Batch 124 Q-Learning Episode Data :  -4.678794634000218
# Batch 125 Q-Learning Episode Data :  -4.8383560363758775
# Batch 126 Q-Learning Episode Data :  -5.395544403497711
# Batch 127 Q-Learning Episode Data :  -4.594051493852807
# Batch 128 Q-Learning Episode Data :  -4.584032036052408
# Batch 129 Q-Learning Episode Data :  -5.154943343028301
# Batch 130 Q-Learning Episode Data :  -5.087826359482228
# Batch 131 Q-Learning Episode Data :  -5.605880263080245
# Batch 132 Q-Learning Episode Data :  -4.919326871995107
# Batch 133 Q-Learning Episode Data :  -4.938345885222355
# Batch 134 Q-Learning Episode Data :  -5.600922626073792
# Batch 135 Q-Learning Episode Data :  -4.914360408987443
# Batch 136 Q-Learning Episode Data :  -5.0116916286597135
# Batch 137 Q-Learning Episode Data :  -5.18507859299894
# Batch 138 Q-Learning Episode Data :  -5.592108535169493
# Batch 139 Q-Learning Episode Data :  -5.924391214024601
# Batch 140 Q-Learning Episode Data :  -5.5205205758249125
# Batch 141 Q-Learning Episode Data :  -5.476748728315554
# Batch 142 Q-Learning Episode Data :  -5.133952575816232
# Batch 143 Q-Learning Episode Data :  -5.019555379494721
# Batch 144 Q-Learning Episode Data :  -5.140714805315579
# Batch 145 Q-Learning Episode Data :  -5.794043866382912
# Batch 146 Q-Learning Episode Data :  -5.075438340121794
# Batch 147 Q-Learning Episode Data :  -5.322969371568833
# Batch 148 Q-Learning Episode Data :  -5.362050189955771
# Batch 149 Q-Learning Episode Data :  -5.283446723667218
# Batch 150 Q-Learning Episode Data :  -5.706311250459212
# Batch 151 Q-Learning Episode Data :  -4.847158745413365
# Batch 152 Q-Learning Episode Data :  -4.525638051577035
# Batch 153 Q-Learning Episode Data :  -5.835025705019683
# Batch 154 Q-Learning Episode Data :  -5.9993697981259295
# Batch 155 Q-Learning Episode Data :  -5.049103138692858
# Batch 156 Q-Learning Episode Data :  -5.1004385725460235
# Batch 157 Q-Learning Episode Data :  -5.088030591971086
# Batch 158 Q-Learning Episode Data :  -5.285789798120921
# Batch 159 Q-Learning Episode Data :  -4.77730374059095
# Batch 160 Q-Learning Episode Data :  -5.022643839219629
# Batch 161 Q-Learning Episode Data :  -3.9969158031592227
# Batch 162 Q-Learning Episode Data :  -4.527211482835
# Batch 163 Q-Learning Episode Data :  -5.450400737296935
# Batch 164 Q-Learning Episode Data :  -5.750526443822426
# Batch 165 Q-Learning Episode Data :  -5.3984547984499835
# Batch 166 Q-Learning Episode Data :  -4.756763475256836
# Batch 167 Q-Learning Episode Data :  -5.0918602089773035
# Batch 168 Q-Learning Episode Data :  -5.137814160680537
# Batch 169 Q-Learning Episode Data :  -5.357773243116592
# Batch 170 Q-Learning Episode Data :  -5.4983175358117675
# Batch 171 Q-Learning Episode Data :  -4.533995680104587
# Batch 172 Q-Learning Episode Data :  -4.764625613256232
# Batch 173 Q-Learning Episode Data :  -4.8508501206100405
# Batch 174 Q-Learning Episode Data :  -5.310559142886512
# Batch 175 Q-Learning Episode Data :  -4.58997025293962
# Batch 176 Q-Learning Episode Data :  -5.074636833032769
# Batch 177 Q-Learning Episode Data :  -5.397044105330522
# Batch 178 Q-Learning Episode Data :  -5.407724655573346
# Batch 179 Q-Learning Episode Data :  -5.768844126599897
# Batch 180 Q-Learning Episode Data :  -5.109474337184238
# Batch 181 Q-Learning Episode Data :  -4.452318608045702
# Batch 182 Q-Learning Episode Data :  -4.037868960134768
# Batch 183 Q-Learning Episode Data :  -4.618832757966797
# Batch 184 Q-Learning Episode Data :  -5.045903496819024
# Batch 185 Q-Learning Episode Data :  -4.237793709400542
# Batch 186 Q-Learning Episode Data :  -5.034492892508536
# Batch 187 Q-Learning Episode Data :  -4.55756513206949
# Batch 188 Q-Learning Episode Data :  -5.182445799073996
# Batch 189 Q-Learning Episode Data :  -5.547098662483293
# Batch 190 Q-Learning Episode Data :  -3.8824758571740254
# Batch 191 Q-Learning Episode Data :  -5.104060425490173
# Batch 192 Q-Learning Episode Data :  -5.398564413029502
# Batch 193 Q-Learning Episode Data :  -4.982591028441427
# Batch 194 Q-Learning Episode Data :  -4.343058315829764
# Batch 195 Q-Learning Episode Data :  -5.230147080603318
# Batch 196 Q-Learning Episode Data :  -5.8185646546705145
# Batch 197 Q-Learning Episode Data :  -5.034856327722966
# Batch 198 Q-Learning Episode Data :  -5.291909761186208
# Batch 199 Q-Learning Episode Data :  -5.84547962375171
# Batch 200 Q-Learning Episode Data :  -4.805684961129882
# Batch 201 Q-Learning Episode Data :  -4.582667796183573
# Batch 202 Q-Learning Episode Data :  -4.820625209246146
# Batch 203 Q-Learning Episode Data :  -4.67761760178829
# Batch 204 Q-Learning Episode Data :  -4.3668302586702765
# Batch 205 Q-Learning Episode Data :  -5.188032109337998
# Batch 206 Q-Learning Episode Data :  -5.625700624682658
# Batch 207 Q-Learning Episode Data :  -4.374452028725148
# Batch 208 Q-Learning Episode Data :  -5.378637507622123
# Batch 209 Q-Learning Episode Data :  -4.927546765974014
# Batch 210 Q-Learning Episode Data :  -5.0129835112657135
# Batch 211 Q-Learning Episode Data :  -5.388499416408383
# Batch 212 Q-Learning Episode Data :  -4.920632226142524
# Batch 213 Q-Learning Episode Data :  -4.856731517280656
# Batch 214 Q-Learning Episode Data :  -4.57729203447502
# Batch 215 Q-Learning Episode Data :  -4.997167331025435
# Batch 216 Q-Learning Episode Data :  -5.521525654795553
# Batch 217 Q-Learning Episode Data :  -5.553084051755711
# Batch 218 Q-Learning Episode Data :  -5.277341933276402
# Batch 219 Q-Learning Episode Data :  -4.622605472752861
# Batch 220 Q-Learning Episode Data :  -5.249624164958196
# Batch 221 Q-Learning Episode Data :  -4.862169512803305
# Batch 222 Q-Learning Episode Data :  -5.20239496113247
# Batch 223 Q-Learning Episode Data :  -5.07049934076411
# Batch 224 Q-Learning Episode Data :  -5.302709133386866
# Batch 225 Q-Learning Episode Data :  -5.157468556783072
# Batch 226 Q-Learning Episode Data :  -5.2670901028825865
# Batch 227 Q-Learning Episode Data :  -4.875297456903873
# Batch 228 Q-Learning Episode Data :  -5.446028058904907
# Batch 229 Q-Learning Episode Data :  -5.170516838497514
# Batch 230 Q-Learning Episode Data :  -4.322642424300615
# Batch 231 Q-Learning Episode Data :  -5.057765554199369
# Batch 232 Q-Learning Episode Data :  -4.470023907484611
# Batch 233 Q-Learning Episode Data :  -5.021125146046162
# Batch 234 Q-Learning Episode Data :  -5.234313861065779
# Batch 235 Q-Learning Episode Data :  -5.20391812647934
# Batch 236 Q-Learning Episode Data :  -5.339878673117817
# Batch 237 Q-Learning Episode Data :  -4.68839410973094
# Batch 238 Q-Learning Episode Data :  -5.2419767521108085
# Batch 239 Q-Learning Episode Data :  -5.4322785702437075
# Batch 240 Q-Learning Episode Data :  -5.044606679998516
# Batch 241 Q-Learning Episode Data :  -4.814613029273287
# Batch 242 Q-Learning Episode Data :  -5.100138674206796
# Batch 243 Q-Learning Episode Data :  -5.330198570183853
# Batch 244 Q-Learning Episode Data :  -4.93295257945473
# Batch 245 Q-Learning Episode Data :  -5.2786950546583835
# Batch 246 Q-Learning Episode Data :  -4.915656179282177
# Batch 247 Q-Learning Episode Data :  -5.436883035834681
# Batch 248 Q-Learning Episode Data :  -5.208221006432662
# Batch 249 Q-Learning Episode Data :  -5.8996841732726875
# Batch 250 Q-Learning Episode Data :  -5.411003620746308
# Batch 251 Q-Learning Episode Data :  -4.927363099931937
# Batch 252 Q-Learning Episode Data :  -4.708375277782314
# Batch 253 Q-Learning Episode Data :  -4.984839235803304
# Batch 254 Q-Learning Episode Data :  -4.958981211531465
# Batch 255 Q-Learning Episode Data :  -5.191080569475418
# Batch 256 Q-Learning Episode Data :  -5.136543198155453
# Batch 257 Q-Learning Episode Data :  -5.298889437341475
# Batch 258 Q-Learning Episode Data :  -5.407722044055322
# Batch 259 Q-Learning Episode Data :  -5.155463550899475
# Batch 260 Q-Learning Episode Data :  -4.401167927703464
# Batch 261 Q-Learning Episode Data :  -4.52600794678885
# Batch 262 Q-Learning Episode Data :  -5.434964326638225
# Batch 263 Q-Learning Episode Data :  -5.13538970255594
# Batch 264 Q-Learning Episode Data :  -5.805493659127077
# Batch 265 Q-Learning Episode Data :  -4.832088631287425
# Batch 266 Q-Learning Episode Data :  -5.174168575540056
# Batch 267 Q-Learning Episode Data :  -4.485155549388133
# Batch 268 Q-Learning Episode Data :  -5.757881649010615
# Batch 269 Q-Learning Episode Data :  -4.45812861041743
# Batch 270 Q-Learning Episode Data :  -4.150640181417653
# Batch 271 Q-Learning Episode Data :  -4.963595305509051
# Batch 272 Q-Learning Episode Data :  -5.0977601746397605
# Batch 273 Q-Learning Episode Data :  -5.3397549584703965
# Batch 274 Q-Learning Episode Data :  -4.4262855291596335
# Batch 275 Q-Learning Episode Data :  -4.981738392079757
# Batch 276 Q-Learning Episode Data :  -5.179802276111892
# Batch 277 Q-Learning Episode Data :  -5.624891635493403
# Batch 278 Q-Learning Episode Data :  -5.6943660619330965
# Batch 279 Q-Learning Episode Data :  -4.32370651344496
# Batch 280 Q-Learning Episode Data :  -5.557707750617313
# Batch 281 Q-Learning Episode Data :  -4.474440160662676
# Batch 282 Q-Learning Episode Data :  -5.338994773256242
# Batch 283 Q-Learning Episode Data :  -4.435870306786533
# Batch 284 Q-Learning Episode Data :  -4.6321057442577
# Batch 285 Q-Learning Episode Data :  -5.570690442098068
# Batch 286 Q-Learning Episode Data :  -5.067593034901649
# Batch 287 Q-Learning Episode Data :  -5.4177899302400965
# Batch 288 Q-Learning Episode Data :  -4.964199210829519
# Batch 289 Q-Learning Episode Data :  -5.126988281424056
# Batch 290 Q-Learning Episode Data :  -5.475166027457029
# Batch 291 Q-Learning Episode Data :  -5.050967396714884
# Batch 292 Q-Learning Episode Data :  -5.359911325036164
# Batch 293 Q-Learning Episode Data :  -5.375695555196986
# Batch 294 Q-Learning Episode Data :  -5.076035351888491
# Batch 295 Q-Learning Episode Data :  -4.950327211346365
# Batch 296 Q-Learning Episode Data :  -5.118671830465825
# Batch 297 Q-Learning Episode Data :  -4.9200906824635755
# Batch 298 Q-Learning Episode Data :  -4.962627418169929
# Batch 299 Q-Learning Episode Data :  -5.141442488098836
# Batch 300 Q-Learning Episode Data :  -4.894570459432812
# Batch 301 Q-Learning Episode Data :  -5.496699260007686
# Batch 302 Q-Learning Episode Data :  -5.189342853730511
# Batch 303 Q-Learning Episode Data :  -5.604005198366861
# Batch 304 Q-Learning Episode Data :  -4.9755234871598795
# Batch 305 Q-Learning Episode Data :  -5.232106905570782
# Batch 306 Q-Learning Episode Data :  -5.080642925644808
# Batch 307 Q-Learning Episode Data :  -5.151570636667203
# Batch 308 Q-Learning Episode Data :  -4.766407282112394
# Batch 309 Q-Learning Episode Data :  -5.264437943955942
# Batch 310 Q-Learning Episode Data :  -4.486960737188797
# Batch 311 Q-Learning Episode Data :  -4.859982875682975
# Batch 312 Q-Learning Episode Data :  -4.70222005114015
# Batch 313 Q-Learning Episode Data :  -4.752032246401361
# Batch 314 Q-Learning Episode Data :  -5.04578816542255
# Batch 315 Q-Learning Episode Data :  -4.596029782554381
# Batch 316 Q-Learning Episode Data :  -4.874822434155657
# Batch 317 Q-Learning Episode Data :  -5.259278431559359
# Batch 318 Q-Learning Episode Data :  -5.607995777213371
# Batch 319 Q-Learning Episode Data :  -5.199409606707805
# Batch 320 Q-Learning Episode Data :  -4.789370292240382
# Batch 321 Q-Learning Episode Data :  -5.146896246133619
# Batch 322 Q-Learning Episode Data :  -5.171797959496999
# Batch 323 Q-Learning Episode Data :  -5.259197498495993
# Batch 324 Q-Learning Episode Data :  -5.234017697383517
# Batch 325 Q-Learning Episode Data :  -4.1959652736932185
# Batch 326 Q-Learning Episode Data :  -4.941549790089555
# Batch 327 Q-Learning Episode Data :  -5.305502168201557
# Batch 328 Q-Learning Episode Data :  -4.6171168080164735
# Batch 329 Q-Learning Episode Data :  -4.692830792233374
# Batch 330 Q-Learning Episode Data :  -5.308329882604328
# Batch 331 Q-Learning Episode Data :  -6.205245995885432
# Batch 332 Q-Learning Episode Data :  -5.120469099295445
# Batch 333 Q-Learning Episode Data :  -4.981007432962407
# Batch 334 Q-Learning Episode Data :  -4.823346189188572
# Batch 335 Q-Learning Episode Data :  -5.196598892364457
# Batch 336 Q-Learning Episode Data :  -4.793584667163473
# Batch 337 Q-Learning Episode Data :  -5.221697138101105
# Batch 338 Q-Learning Episode Data :  -5.3834315360309075
# Batch 339 Q-Learning Episode Data :  -4.712049719863675
# Batch 340 Q-Learning Episode Data :  -4.833032789393501
# Batch 341 Q-Learning Episode Data :  -5.275844975220705
# Batch 342 Q-Learning Episode Data :  -4.680159002380595
# Batch 343 Q-Learning Episode Data :  -5.424657286527953
# Batch 344 Q-Learning Episode Data :  -4.665850999794983
# Batch 345 Q-Learning Episode Data :  -4.720992236200128
# Batch 346 Q-Learning Episode Data :  -5.225980834334303
# Batch 347 Q-Learning Episode Data :  -5.412693297410611
# Batch 348 Q-Learning Episode Data :  -5.080105201720363
# Batch 349 Q-Learning Episode Data :  -5.6291115710519914
# Batch 350 Q-Learning Episode Data :  -5.7724311715109575
# Batch 351 Q-Learning Episode Data :  -5.168071855601052
# Batch 352 Q-Learning Episode Data :  -4.479215231198114
# Batch 353 Q-Learning Episode Data :  -4.9793271181544725
# Batch 354 Q-Learning Episode Data :  -5.274816197035649
# Batch 355 Q-Learning Episode Data :  -5.253722515270825
# Batch 356 Q-Learning Episode Data :  -4.718832522178949
# Batch 357 Q-Learning Episode Data :  -5.634332255468293
# Batch 358 Q-Learning Episode Data :  -5.287931921775768
# Batch 359 Q-Learning Episode Data :  -5.452424764164264
# Batch 360 Q-Learning Episode Data :  -4.814033790772949
# Batch 361 Q-Learning Episode Data :  -5.1406844070419115
# Batch 362 Q-Learning Episode Data :  -5.174647880553375
# Batch 363 Q-Learning Episode Data :  -5.059492820467195
# Batch 364 Q-Learning Episode Data :  -4.6838318471255524
# Batch 365 Q-Learning Episode Data :  -4.87027934900062
# Batch 366 Q-Learning Episode Data :  -4.711295648708922
# Batch 367 Q-Learning Episode Data :  -5.169227344428341
# Batch 368 Q-Learning Episode Data :  -4.646404889586779
# Batch 369 Q-Learning Episode Data :  -5.577064589954759
# Batch 370 Q-Learning Episode Data :  -5.6844419542323426
# Batch 371 Q-Learning Episode Data :  -5.594980397209239
# Batch 372 Q-Learning Episode Data :  -5.271327688814946
# Batch 373 Q-Learning Episode Data :  -4.896780289088162
# Batch 374 Q-Learning Episode Data :  -5.318076330822297
# Batch 375 Q-Learning Episode Data :  -5.122840034789332
# Batch 376 Q-Learning Episode Data :  -5.279391544237499
# Batch 377 Q-Learning Episode Data :  -5.495817764813181
# Batch 378 Q-Learning Episode Data :  -4.476373582874817
# Batch 379 Q-Learning Episode Data :  -5.203279064295581
# Batch 380 Q-Learning Episode Data :  -4.664571614440533
# Batch 381 Q-Learning Episode Data :  -4.87865589294003
# Batch 382 Q-Learning Episode Data :  -5.109732019935595
# Batch 383 Q-Learning Episode Data :  -5.118099677975528
# Batch 384 Q-Learning Episode Data :  -4.750766059547526
# Batch 385 Q-Learning Episode Data :  -4.887230406732756
# Batch 386 Q-Learning Episode Data :  -4.872021011796359
# Batch 387 Q-Learning Episode Data :  -4.723439285317995
# Batch 388 Q-Learning Episode Data :  -5.506023903752421
# Batch 389 Q-Learning Episode Data :  -4.634491278274148
# Batch 390 Q-Learning Episode Data :  -5.204052867293865
# Batch 391 Q-Learning Episode Data :  -5.789108797605809
# Batch 392 Q-Learning Episode Data :  -5.509118514365275
# Batch 393 Q-Learning Episode Data :  -4.938426857852014
# Batch 394 Q-Learning Episode Data :  -4.597519765830381
# Batch 395 Q-Learning Episode Data :  -5.423958500420225
# Batch 396 Q-Learning Episode Data :  -6.087374589697781
# Batch 397 Q-Learning Episode Data :  -4.89405921322087
# Batch 398 Q-Learning Episode Data :  -4.747054095813486
# Batch 399 Q-Learning Episode Data :  -4.951453966527273
# Batch 400 Q-Learning Episode Data :  -5.2987760907471255
# Batch 401 Q-Learning Episode Data :  -4.732122552861116
# Batch 402 Q-Learning Episode Data :  -4.931385609882523
# Batch 403 Q-Learning Episode Data :  -4.521963145966797
# Batch 404 Q-Learning Episode Data :  -4.885198866518271
# Batch 405 Q-Learning Episode Data :  -5.003830351292831
# Batch 406 Q-Learning Episode Data :  -5.171041409111681
# Batch 407 Q-Learning Episode Data :  -5.918361738940494
# Batch 408 Q-Learning Episode Data :  -5.277633331035983
# Batch 409 Q-Learning Episode Data :  -4.452384300896056
# Batch 410 Q-Learning Episode Data :  -4.510403405807226
# Batch 411 Q-Learning Episode Data :  -4.565675250139801
# Batch 412 Q-Learning Episode Data :  -5.246949255865933
# Batch 413 Q-Learning Episode Data :  -5.3232188327288545
# Batch 414 Q-Learning Episode Data :  -5.317451411896271
# Batch 415 Q-Learning Episode Data :  -5.555499536416153
# Batch 416 Q-Learning Episode Data :  -4.9154307852573105
# Batch 417 Q-Learning Episode Data :  -4.381104914604789
# Batch 418 Q-Learning Episode Data :  -4.981836121457019
# Batch 419 Q-Learning Episode Data :  -5.553955794429083
# Batch 420 Q-Learning Episode Data :  -5.5115159313274695
# Batch 421 Q-Learning Episode Data :  -5.313911933337523
# Batch 422 Q-Learning Episode Data :  -5.298041831433329
# Batch 423 Q-Learning Episode Data :  -4.884917721179285
# Batch 424 Q-Learning Episode Data :  -5.147377612174515
# Batch 425 Q-Learning Episode Data :  -4.76852005190723
# Batch 426 Q-Learning Episode Data :  -4.692392137591722
# Batch 427 Q-Learning Episode Data :  -5.0426240785605545
# Batch 428 Q-Learning Episode Data :  -5.743553400909512
# Batch 429 Q-Learning Episode Data :  -5.395661616240869
# Batch 430 Q-Learning Episode Data :  -5.531932445783724
# Batch 431 Q-Learning Episode Data :  -5.225833103266518
# Batch 432 Q-Learning Episode Data :  -4.500704788828837
# Batch 433 Q-Learning Episode Data :  -5.02232438984537
# Batch 434 Q-Learning Episode Data :  -4.963943011322405
# Batch 435 Q-Learning Episode Data :  -4.84051048926791
# Batch 436 Q-Learning Episode Data :  -5.065932112029281
# Batch 437 Q-Learning Episode Data :  -4.802576828818638
# Batch 438 Q-Learning Episode Data :  -4.644523979178431
# Batch 439 Q-Learning Episode Data :  -4.283010823115491
# Batch 440 Q-Learning Episode Data :  -5.0493486880746925
# Batch 441 Q-Learning Episode Data :  -4.944489900411847
# Batch 442 Q-Learning Episode Data :  -5.047176866790481
# Batch 443 Q-Learning Episode Data :  -4.967008049511982
# Batch 444 Q-Learning Episode Data :  -5.093777736887713
# Batch 445 Q-Learning Episode Data :  -5.822818796750591
# Batch 446 Q-Learning Episode Data :  -5.091311922374363
# Batch 447 Q-Learning Episode Data :  -5.024330695656671
# Batch 448 Q-Learning Episode Data :  -4.701445228646207
# Batch 449 Q-Learning Episode Data :  -5.024054248897198
# Batch 450 Q-Learning Episode Data :  -5.439650749415322
# Batch 451 Q-Learning Episode Data :  -5.109033390707256
# Batch 452 Q-Learning Episode Data :  -4.492180102006411
# Batch 453 Q-Learning Episode Data :  -4.693277942354381
# Batch 454 Q-Learning Episode Data :  -4.374128845339608
# Batch 455 Q-Learning Episode Data :  -4.773504228416744
# Batch 456 Q-Learning Episode Data :  -4.869019311151147
# Batch 457 Q-Learning Episode Data :  -4.995281840762491
# Batch 458 Q-Learning Episode Data :  -5.0366774510701
# Batch 459 Q-Learning Episode Data :  -5.571655365887124
# Batch 460 Q-Learning Episode Data :  -5.66092525528862
# Batch 461 Q-Learning Episode Data :  -4.6219561636620545
# Batch 462 Q-Learning Episode Data :  -4.66918409219334
# Batch 463 Q-Learning Episode Data :  -4.704654157834801
# Batch 464 Q-Learning Episode Data :  -5.422410369575973
# Batch 465 Q-Learning Episode Data :  -4.465104400305092
# Batch 466 Q-Learning Episode Data :  -5.489709615635453
# Batch 467 Q-Learning Episode Data :  -5.379973725377326
# Batch 468 Q-Learning Episode Data :  -4.256942962087639
# Batch 469 Q-Learning Episode Data :  -4.729517641932446
# Batch 470 Q-Learning Episode Data :  -4.8110968647211685
# Batch 471 Q-Learning Episode Data :  -4.985218227402088
# Batch 472 Q-Learning Episode Data :  -4.715075187499172
# Batch 473 Q-Learning Episode Data :  -4.575232183072253
# Batch 474 Q-Learning Episode Data :  -4.656900285814645
# Batch 475 Q-Learning Episode Data :  -5.565127630960851
# Batch 476 Q-Learning Episode Data :  -5.189240125180528
# Batch 477 Q-Learning Episode Data :  -4.972341715997167
# Batch 478 Q-Learning Episode Data :  -5.64737151548305
# Batch 479 Q-Learning Episode Data :  -5.177801191606944
# Batch 480 Q-Learning Episode Data :  -5.099175733551072
# Batch 481 Q-Learning Episode Data :  -4.9364819704968586
# Batch 482 Q-Learning Episode Data :  -5.123012957952177
# Batch 483 Q-Learning Episode Data :  -5.311571380579522
# Batch 484 Q-Learning Episode Data :  -4.5523887127532925
# Batch 485 Q-Learning Episode Data :  -5.057810673615349
# Batch 486 Q-Learning Episode Data :  -5.110187053702024
# Batch 487 Q-Learning Episode Data :  -5.354575266195751
# Batch 488 Q-Learning Episode Data :  -4.695353252910393
# Batch 489 Q-Learning Episode Data :  -5.2380733914387765
# Batch 490 Q-Learning Episode Data :  -4.787813290991369
# Batch 491 Q-Learning Episode Data :  -5.420227251707435
# Batch 492 Q-Learning Episode Data :  -5.5831211359109005
# Batch 493 Q-Learning Episode Data :  -5.260786673290436
# Batch 494 Q-Learning Episode Data :  -4.054953484962342
# Batch 495 Q-Learning Episode Data :  -5.358762775702266
# Batch 496 Q-Learning Episode Data :  -4.559328937991145
# Batch 497 Q-Learning Episode Data :  -5.0673832128348755
# Batch 498 Q-Learning Episode Data :  -5.480790369496075
# Batch 499 Q-Learning Episode Data :  -5.661814226010572
# Batch 500 Q-Learning Episode Data :  -4.98428582024548
# Batch 501 Q-Learning Episode Data :  -4.577208259585263
# Batch 502 Q-Learning Episode Data :  -4.91361075814484
# Batch 503 Q-Learning Episode Data :  -4.576626895601024
# Batch 504 Q-Learning Episode Data :  -4.994588456922549
# Batch 505 Q-Learning Episode Data :  -4.94870488391416
# Batch 506 Q-Learning Episode Data :  -5.053439668244869
# Batch 507 Q-Learning Episode Data :  -5.659717939452853
# Batch 508 Q-Learning Episode Data :  -4.654966538356127
# Batch 509 Q-Learning Episode Data :  -4.765072568100642
# Batch 510 Q-Learning Episode Data :  -4.734085665765979
# Batch 511 Q-Learning Episode Data :  -4.991822774869638
# Batch 512 Q-Learning Episode Data :  -4.680960294924617
# Batch 513 Q-Learning Episode Data :  -4.849491599967443
# Batch 514 Q-Learning Episode Data :  -4.547334274684045
# Batch 515 Q-Learning Episode Data :  -5.251981880164811
# Batch 516 Q-Learning Episode Data :  -5.7831133999726845
# Batch 517 Q-Learning Episode Data :  -4.3984052071556325
# Batch 518 Q-Learning Episode Data :  -5.053371452469519
# Batch 519 Q-Learning Episode Data :  -4.971582006935737
# Batch 520 Q-Learning Episode Data :  -5.3359210956051
# Batch 521 Q-Learning Episode Data :  -4.857384260257584
# Batch 522 Q-Learning Episode Data :  -5.1452237126030544
# Batch 523 Q-Learning Episode Data :  -4.837488241085072
# Batch 524 Q-Learning Episode Data :  -4.654519742351129
# Batch 525 Q-Learning Episode Data :  -5.222153320351922
# Batch 526 Q-Learning Episode Data :  -5.071491807520645
# Batch 527 Q-Learning Episode Data :  -4.865031848773092
# Batch 528 Q-Learning Episode Data :  -4.537954620886392
# Batch 529 Q-Learning Episode Data :  -4.995387947574998
# Batch 530 Q-Learning Episode Data :  -4.703442485803682
# Batch 531 Q-Learning Episode Data :  -4.852335787540734
# Batch 532 Q-Learning Episode Data :  -4.495996188064949
# Batch 533 Q-Learning Episode Data :  -4.923442085835704
# Batch 534 Q-Learning Episode Data :  -5.3489272503028955
# Batch 535 Q-Learning Episode Data :  -4.149545395278308
# Batch 536 Q-Learning Episode Data :  -4.400275212787964
# Batch 537 Q-Learning Episode Data :  -4.480714518135652
# Batch 538 Q-Learning Episode Data :  -5.380667889707705
# Batch 539 Q-Learning Episode Data :  -5.382940531923839
# Batch 540 Q-Learning Episode Data :  -5.199815074744058
# Batch 541 Q-Learning Episode Data :  -4.929331113021922
# Batch 542 Q-Learning Episode Data :  -5.040810542375949
# Batch 543 Q-Learning Episode Data :  -5.513567041292253
# Batch 544 Q-Learning Episode Data :  -5.242579341909424
# Batch 545 Q-Learning Episode Data :  -5.101214148665997
# Batch 546 Q-Learning Episode Data :  -4.416398205028645
# Batch 547 Q-Learning Episode Data :  -5.736055474949158
# Batch 548 Q-Learning Episode Data :  -4.693959589358289
# Batch 549 Q-Learning Episode Data :  -4.837943074185737
# Batch 550 Q-Learning Episode Data :  -4.969482835138891
# Batch 551 Q-Learning Episode Data :  -5.7588311288732505
# Batch 552 Q-Learning Episode Data :  -5.3568175545412595
# Batch 553 Q-Learning Episode Data :  -5.275857540410513
# Batch 554 Q-Learning Episode Data :  -4.1434360557284835
# Batch 555 Q-Learning Episode Data :  -4.9573855361676245
# Batch 556 Q-Learning Episode Data :  -5.918391040875075
# Batch 557 Q-Learning Episode Data :  -5.897613841432779
# Batch 558 Q-Learning Episode Data :  -4.72853039638065
# Batch 559 Q-Learning Episode Data :  -4.751819963016046
# Batch 560 Q-Learning Episode Data :  -4.548233852251214
# Batch 561 Q-Learning Episode Data :  -5.535480926523767
# Batch 562 Q-Learning Episode Data :  -5.31358758246917
# Batch 563 Q-Learning Episode Data :  -4.967661045985234
# Batch 564 Q-Learning Episode Data :  -5.078797524136889
# Batch 565 Q-Learning Episode Data :  -4.6850210778566215
# Batch 566 Q-Learning Episode Data :  -5.952977056944495
# Batch 567 Q-Learning Episode Data :  -4.984290487975975
# Batch 568 Q-Learning Episode Data :  -5.471201093768039
# Batch 569 Q-Learning Episode Data :  -4.899633442704801
# Batch 570 Q-Learning Episode Data :  -5.43194965836937
# Batch 571 Q-Learning Episode Data :  -5.028545353658532
# Batch 572 Q-Learning Episode Data :  -5.066974975635895
# Batch 573 Q-Learning Episode Data :  -4.952616014297176
# Batch 574 Q-Learning Episode Data :  -5.091342934631998
# Batch 575 Q-Learning Episode Data :  -4.854817942982133
# Batch 576 Q-Learning Episode Data :  -4.80538267985574
# Batch 577 Q-Learning Episode Data :  -4.440680242524726
# Batch 578 Q-Learning Episode Data :  -4.7354081623580235
# Batch 579 Q-Learning Episode Data :  -4.821904163980842
# Batch 580 Q-Learning Episode Data :  -4.747925995041735
# Batch 581 Q-Learning Episode Data :  -4.858336546333302
# Batch 582 Q-Learning Episode Data :  -5.296082982521157
# Batch 583 Q-Learning Episode Data :  -4.597148630020528
# Batch 584 Q-Learning Episode Data :  -4.479283211456619
# Batch 585 Q-Learning Episode Data :  -5.190546966581943
# Batch 586 Q-Learning Episode Data :  -5.013620175095548
# Batch 587 Q-Learning Episode Data :  -5.643667368307871
# Batch 588 Q-Learning Episode Data :  -5.239391722732865
# Batch 589 Q-Learning Episode Data :  -4.046969493996854
# Batch 590 Q-Learning Episode Data :  -4.754177525643526
# Batch 591 Q-Learning Episode Data :  -4.099895734412406
# Batch 592 Q-Learning Episode Data :  -5.2450633606704695
# Batch 593 Q-Learning Episode Data :  -6.166784676839956
# Batch 594 Q-Learning Episode Data :  -5.8748256079331815
# Batch 595 Q-Learning Episode Data :  -4.540220852767473
# Batch 596 Q-Learning Episode Data :  -5.360183939351792
# Batch 597 Q-Learning Episode Data :  -4.989870539228264
# Batch 598 Q-Learning Episode Data :  -5.016124805742294
# Batch 599 Q-Learning Episode Data :  -5.141026086321661
# Batch 600 Q-Learning Episode Data :  -4.982330486298496
# Batch 601 Q-Learning Episode Data :  -5.142843224466567
# Batch 602 Q-Learning Episode Data :  -4.928673663071638
# Batch 603 Q-Learning Episode Data :  -5.307248475780812
# Batch 604 Q-Learning Episode Data :  -4.897491853730821
# Batch 605 Q-Learning Episode Data :  -4.917516364429235
# Batch 606 Q-Learning Episode Data :  -5.168324638172719
# Batch 607 Q-Learning Episode Data :  -4.911422100450794
# Batch 608 Q-Learning Episode Data :  -5.390581512745399
# Batch 609 Q-Learning Episode Data :  -5.023242064729358
# Batch 610 Q-Learning Episode Data :  -5.245827348733414
# Batch 611 Q-Learning Episode Data :  -4.659925601996327
# Batch 612 Q-Learning Episode Data :  -4.824873303966162
# Batch 613 Q-Learning Episode Data :  -4.836994700484488
# Batch 614 Q-Learning Episode Data :  -5.132582961006488
# Batch 615 Q-Learning Episode Data :  -5.371982072582404
# Batch 616 Q-Learning Episode Data :  -4.51412517630137
# Batch 617 Q-Learning Episode Data :  -5.515214227612388
# Batch 618 Q-Learning Episode Data :  -5.315249405212335
# Batch 619 Q-Learning Episode Data :  -5.310972247395036
# Batch 620 Q-Learning Episode Data :  -5.494320379027205
# Batch 621 Q-Learning Episode Data :  -5.523374728175942
# Batch 622 Q-Learning Episode Data :  -5.547105422882493
# Batch 623 Q-Learning Episode Data :  -5.335370096051977
# Batch 624 Q-Learning Episode Data :  -4.750316515348311
# Batch 625 Q-Learning Episode Data :  -5.129577818206426
# Batch 626 Q-Learning Episode Data :  -5.801205085965526
# Batch 627 Q-Learning Episode Data :  -4.686907613724787
# Batch 628 Q-Learning Episode Data :  -4.895556358484072
# Batch 629 Q-Learning Episode Data :  -5.2156082157655845
# Batch 630 Q-Learning Episode Data :  -4.474931298385535
# Batch 631 Q-Learning Episode Data :  -5.055061153053722
# Batch 632 Q-Learning Episode Data :  -5.164156179341336
# Batch 633 Q-Learning Episode Data :  -5.185092790032063
# Batch 634 Q-Learning Episode Data :  -4.287779155700404
# Batch 635 Q-Learning Episode Data :  -5.0679409792155345
# Batch 636 Q-Learning Episode Data :  -5.465791998396691
# Batch 637 Q-Learning Episode Data :  -5.877506060157453
# Batch 638 Q-Learning Episode Data :  -4.5167044453003795
# Batch 639 Q-Learning Episode Data :  -5.2425930837084005
# Batch 640 Q-Learning Episode Data :  -5.515551933027263
# Batch 641 Q-Learning Episode Data :  -4.976255239645708
# Batch 642 Q-Learning Episode Data :  -4.43288657720104
# Batch 643 Q-Learning Episode Data :  -5.227991190907739
# Batch 644 Q-Learning Episode Data :  -4.73630159857638
# Batch 645 Q-Learning Episode Data :  -4.841255416572859
# Batch 646 Q-Learning Episode Data :  -4.72732494318522
# Batch 647 Q-Learning Episode Data :  -5.991149184262006
# Batch 648 Q-Learning Episode Data :  -4.610854644479496
# Batch 649 Q-Learning Episode Data :  -5.204249345856442
# Batch 650 Q-Learning Episode Data :  -5.634746708610656
# Batch 651 Q-Learning Episode Data :  -4.949909174412228
# Batch 652 Q-Learning Episode Data :  -5.254172969042347
# Batch 653 Q-Learning Episode Data :  -5.230467404117045
# Batch 654 Q-Learning Episode Data :  -4.851175830250423
# Batch 655 Q-Learning Episode Data :  -6.4883343243058045
# Batch 656 Q-Learning Episode Data :  -5.402545954028844
# Batch 657 Q-Learning Episode Data :  -4.211035594974574
# Batch 658 Q-Learning Episode Data :  -4.541769569116552
# Batch 659 Q-Learning Episode Data :  -4.689322018656715
# Batch 660 Q-Learning Episode Data :  -4.816717685842822
# Batch 661 Q-Learning Episode Data :  -5.195522353314371
# Batch 662 Q-Learning Episode Data :  -5.498532336551192
# Batch 663 Q-Learning Episode Data :  -5.291638389207008
# Batch 664 Q-Learning Episode Data :  -4.875904027596673
# Batch 665 Q-Learning Episode Data :  -4.831897982065592
# Batch 666 Q-Learning Episode Data :  -5.318853167327727
# Batch 667 Q-Learning Episode Data :  -4.873760510536014
# Batch 668 Q-Learning Episode Data :  -5.218035147884154
# Batch 669 Q-Learning Episode Data :  -4.796140004809819
# Batch 670 Q-Learning Episode Data :  -4.653080094105496
# Batch 671 Q-Learning Episode Data :  -5.118361295318722
# Batch 672 Q-Learning Episode Data :  -4.744376491918507
# Batch 673 Q-Learning Episode Data :  -4.41440588952836
# Batch 674 Q-Learning Episode Data :  -5.264732969392101
# Batch 675 Q-Learning Episode Data :  -5.53878956119096
# Batch 676 Q-Learning Episode Data :  -6.04065575931479
# Batch 677 Q-Learning Episode Data :  -5.186334197617729
# Batch 678 Q-Learning Episode Data :  -5.4454345461140825
# Batch 679 Q-Learning Episode Data :  -5.100586040238669
# Batch 680 Q-Learning Episode Data :  -5.107500082510025
# Batch 681 Q-Learning Episode Data :  -4.309967528602242
# Batch 682 Q-Learning Episode Data :  -5.4569845143108
# Batch 683 Q-Learning Episode Data :  -4.716082010484504
# Batch 684 Q-Learning Episode Data :  -5.030680925189726
# Batch 685 Q-Learning Episode Data :  -4.3019681848447044
# Batch 686 Q-Learning Episode Data :  -4.70496071050536
# Batch 687 Q-Learning Episode Data :  -5.356768558819668
# Batch 688 Q-Learning Episode Data :  -5.091868577569524
# Batch 689 Q-Learning Episode Data :  -5.283079674519486
# Batch 690 Q-Learning Episode Data :  -4.188350145211515
# Batch 691 Q-Learning Episode Data :  -4.712722604405944
# Batch 692 Q-Learning Episode Data :  -4.684886129517191
# Batch 693 Q-Learning Episode Data :  -5.543046527516605
# Batch 694 Q-Learning Episode Data :  -4.601022841985034
# Batch 695 Q-Learning Episode Data :  -5.114664186928891
# Batch 696 Q-Learning Episode Data :  -4.463010675506887
# Batch 697 Q-Learning Episode Data :  -5.121618558909297
# Batch 698 Q-Learning Episode Data :  -4.711243975104889
# Batch 699 Q-Learning Episode Data :  -5.12546133518347
# Batch 700 Q-Learning Episode Data :  -5.121538997636818
# Batch 701 Q-Learning Episode Data :  -4.7332757067970865
# Batch 702 Q-Learning Episode Data :  -5.648367760078195
# Batch 703 Q-Learning Episode Data :  -4.882244616620338
# Batch 704 Q-Learning Episode Data :  -3.8959639648864632
# Batch 705 Q-Learning Episode Data :  -4.453419153493908
# Batch 706 Q-Learning Episode Data :  -4.936695889064887
# Batch 707 Q-Learning Episode Data :  -5.61562236804966
# Batch 708 Q-Learning Episode Data :  -4.270149035032543
# Batch 709 Q-Learning Episode Data :  -5.38743453821118
# Batch 710 Q-Learning Episode Data :  -4.948482189151162
# Batch 711 Q-Learning Episode Data :  -4.5059960749195325
# Batch 712 Q-Learning Episode Data :  -4.444761014244614
# Batch 713 Q-Learning Episode Data :  -5.368734638875574
# Batch 714 Q-Learning Episode Data :  -4.858516462613222
# Batch 715 Q-Learning Episode Data :  -5.103796682868388
# Batch 716 Q-Learning Episode Data :  -4.381212407806203
# Batch 717 Q-Learning Episode Data :  -4.403867892423326
# Batch 718 Q-Learning Episode Data :  -5.400839180590719
# Batch 719 Q-Learning Episode Data :  -4.952176605575665
# Batch 720 Q-Learning Episode Data :  -5.119565525327116
# Batch 721 Q-Learning Episode Data :  -5.267008421376518
# Batch 722 Q-Learning Episode Data :  -5.198134328370736
# Batch 723 Q-Learning Episode Data :  -4.5995941475435975
# Batch 724 Q-Learning Episode Data :  -4.749755097351006
# Batch 725 Q-Learning Episode Data :  -4.35116266229322
# Batch 726 Q-Learning Episode Data :  -5.979409402778432
# Batch 727 Q-Learning Episode Data :  -4.7563430268915425
# Batch 728 Q-Learning Episode Data :  -5.117679547430647
# Batch 729 Q-Learning Episode Data :  -4.7770494070241964
# Batch 730 Q-Learning Episode Data :  -5.110465601036508
# Batch 731 Q-Learning Episode Data :  -4.979774681054562
# Batch 732 Q-Learning Episode Data :  -4.695646566187679
# Batch 733 Q-Learning Episode Data :  -5.270770078450516
# Batch 734 Q-Learning Episode Data :  -4.6011974635974
# Batch 735 Q-Learning Episode Data :  -5.5181732207522565
# Batch 736 Q-Learning Episode Data :  -5.20947592005047
# Batch 737 Q-Learning Episode Data :  -4.76633810569997
# Batch 738 Q-Learning Episode Data :  -4.753607574007376
# Batch 739 Q-Learning Episode Data :  -3.851936746405889
# Batch 740 Q-Learning Episode Data :  -4.843137779712316
# Batch 741 Q-Learning Episode Data :  -5.0407464606892995
# Batch 742 Q-Learning Episode Data :  -4.409878767450571
# Batch 743 Q-Learning Episode Data :  -4.902064772277159
# Batch 744 Q-Learning Episode Data :  -4.836155080172192
# Batch 745 Q-Learning Episode Data :  -5.115787150874201
# Batch 746 Q-Learning Episode Data :  -5.479463797762361
# Batch 747 Q-Learning Episode Data :  -5.570724742643782
# Batch 748 Q-Learning Episode Data :  -5.249772349078709
# Batch 749 Q-Learning Episode Data :  -4.695611304410784
# Batch 750 Q-Learning Episode Data :  -4.609648874481736
# Batch 751 Q-Learning Episode Data :  -4.450084376409324
# Batch 752 Q-Learning Episode Data :  -4.414160911015628
# Batch 753 Q-Learning Episode Data :  -5.117533471509964
# Batch 754 Q-Learning Episode Data :  -5.126734871474921
# Batch 755 Q-Learning Episode Data :  -5.39281808046999
# Batch 756 Q-Learning Episode Data :  -5.057644477166296
# Batch 757 Q-Learning Episode Data :  -4.807006127882252
# Batch 758 Q-Learning Episode Data :  -5.0145250212909405
# Batch 759 Q-Learning Episode Data :  -4.372399493139783
# Batch 760 Q-Learning Episode Data :  -4.397186737115708
# Batch 761 Q-Learning Episode Data :  -5.216552145117685
# Batch 762 Q-Learning Episode Data :  -5.950783523458666
# Batch 763 Q-Learning Episode Data :  -4.70650295180069
# Batch 764 Q-Learning Episode Data :  -5.582847888260655
# Batch 765 Q-Learning Episode Data :  -4.974166538536599
# Batch 766 Q-Learning Episode Data :  -5.62239590000718
# Batch 767 Q-Learning Episode Data :  -5.525042228916697
# Batch 768 Q-Learning Episode Data :  -5.01825555582961
# Batch 769 Q-Learning Episode Data :  -5.008761281028662
# Batch 770 Q-Learning Episode Data :  -4.00015205037932
# Batch 771 Q-Learning Episode Data :  -4.975034779449006
# Batch 772 Q-Learning Episode Data :  -4.881379388653338
# Batch 773 Q-Learning Episode Data :  -5.143795442967334
# Batch 774 Q-Learning Episode Data :  -4.493260444592091
# Batch 775 Q-Learning Episode Data :  -4.796306004847568
# Batch 776 Q-Learning Episode Data :  -4.675159391434413
# Batch 777 Q-Learning Episode Data :  -5.654624947853284
# Batch 778 Q-Learning Episode Data :  -5.083936359088092
# Batch 779 Q-Learning Episode Data :  -4.911593986509319
# Batch 780 Q-Learning Episode Data :  -4.762722195831206
# Batch 781 Q-Learning Episode Data :  -5.352988567710239
# Batch 782 Q-Learning Episode Data :  -5.404972904901861
# Batch 783 Q-Learning Episode Data :  -6.0228833091592735
# Batch 784 Q-Learning Episode Data :  -4.6264315901952635
# Batch 785 Q-Learning Episode Data :  -5.233670963002317
# Batch 786 Q-Learning Episode Data :  -5.170325746931785
# Batch 787 Q-Learning Episode Data :  -5.44789172558967
# Batch 788 Q-Learning Episode Data :  -5.23784752515072
# Batch 789 Q-Learning Episode Data :  -4.895609596300725
# Batch 790 Q-Learning Episode Data :  -5.626091137362259
# Batch 791 Q-Learning Episode Data :  -4.64389666975687
# Batch 792 Q-Learning Episode Data :  -4.008801812319396
# Batch 793 Q-Learning Episode Data :  -4.736131710429309
# Batch 794 Q-Learning Episode Data :  -4.700738475626547
# Batch 795 Q-Learning Episode Data :  -4.818101476701366
# Batch 796 Q-Learning Episode Data :  -4.577137548383693
# Batch 797 Q-Learning Episode Data :  -4.303666993027497
# Batch 798 Q-Learning Episode Data :  -4.6040912329612915
# Batch 799 Q-Learning Episode Data :  -5.44625548879488
# Batch 800 Q-Learning Episode Data :  -4.354785408657155
# Batch 801 Q-Learning Episode Data :  -4.201855709382332
# Batch 802 Q-Learning Episode Data :  -5.522378806631524
# Batch 803 Q-Learning Episode Data :  -4.796663566322182
# Batch 804 Q-Learning Episode Data :  -5.3055204958233855
# Batch 805 Q-Learning Episode Data :  -4.878413818501669
# Batch 806 Q-Learning Episode Data :  -5.496028789683801
# Batch 807 Q-Learning Episode Data :  -5.457336674312762
# Batch 808 Q-Learning Episode Data :  -5.171620630285998
# Batch 809 Q-Learning Episode Data :  -4.435236904816982
# Batch 810 Q-Learning Episode Data :  -5.107439360720741
# Batch 811 Q-Learning Episode Data :  -4.8577915602314405
# Batch 812 Q-Learning Episode Data :  -5.60769799148179
# Batch 813 Q-Learning Episode Data :  -5.605701985581953
# Batch 814 Q-Learning Episode Data :  -5.702835760797196
# Batch 815 Q-Learning Episode Data :  -5.021249394731693
# Batch 816 Q-Learning Episode Data :  -5.543196967933907
# Batch 817 Q-Learning Episode Data :  -4.719443317122294
# Batch 818 Q-Learning Episode Data :  -4.88764037339946
# Batch 819 Q-Learning Episode Data :  -4.966145599402897
# Batch 820 Q-Learning Episode Data :  -4.749190201968634
# Batch 821 Q-Learning Episode Data :  -5.3369333330544135
# Batch 822 Q-Learning Episode Data :  -5.182108645393193
# Batch 823 Q-Learning Episode Data :  -5.0124186458144475
# Batch 824 Q-Learning Episode Data :  -4.680128456772058
# Batch 825 Q-Learning Episode Data :  -4.829521973328115
# Batch 826 Q-Learning Episode Data :  -4.824561856386407
# Batch 827 Q-Learning Episode Data :  -4.761515694353238
# Batch 828 Q-Learning Episode Data :  -5.473159029852148
# Batch 829 Q-Learning Episode Data :  -4.840543065374554
# Batch 830 Q-Learning Episode Data :  -4.758013818486353
# Batch 831 Q-Learning Episode Data :  -5.918928506204151
# Batch 832 Q-Learning Episode Data :  -6.096173611224659
# Batch 833 Q-Learning Episode Data :  -5.275744736368822
# Batch 834 Q-Learning Episode Data :  -5.255482538370801
# Batch 835 Q-Learning Episode Data :  -5.349729542879495
# Batch 836 Q-Learning Episode Data :  -4.6257887332016026
# Batch 837 Q-Learning Episode Data :  -5.424263106420843
# Batch 838 Q-Learning Episode Data :  -5.759755136044899
# Batch 839 Q-Learning Episode Data :  -5.0683067281028675
# Batch 840 Q-Learning Episode Data :  -4.954648030450004
# Batch 841 Q-Learning Episode Data :  -5.6226717947420415
# Batch 842 Q-Learning Episode Data :  -5.045298690613143
# Batch 843 Q-Learning Episode Data :  -4.830901551808399
# Batch 844 Q-Learning Episode Data :  -5.349485538899261
# Batch 845 Q-Learning Episode Data :  -5.03818081880993
# Batch 846 Q-Learning Episode Data :  -4.765517332226863
# Batch 847 Q-Learning Episode Data :  -4.992971051268641
# Batch 848 Q-Learning Episode Data :  -4.976556138713451
# Batch 849 Q-Learning Episode Data :  -5.588708901936781
# Batch 850 Q-Learning Episode Data :  -4.506965636630006
# Batch 851 Q-Learning Episode Data :  -4.788976608325939
# Batch 852 Q-Learning Episode Data :  -4.6761713024607685
# Batch 853 Q-Learning Episode Data :  -4.920159400145247
# Batch 854 Q-Learning Episode Data :  -5.953033746861306
# Batch 855 Q-Learning Episode Data :  -5.167345825349773
# Batch 856 Q-Learning Episode Data :  -5.44562365030189
# Batch 857 Q-Learning Episode Data :  -5.6545696557316205
# Batch 858 Q-Learning Episode Data :  -4.678410620657388
# Batch 859 Q-Learning Episode Data :  -4.067831555285851
# Batch 860 Q-Learning Episode Data :  -4.065654054269745
# Batch 861 Q-Learning Episode Data :  -5.620041002864886
# Batch 862 Q-Learning Episode Data :  -4.719050084265611
# Batch 863 Q-Learning Episode Data :  -5.1676291743047065
# Batch 864 Q-Learning Episode Data :  -4.65950042408155
# Batch 865 Q-Learning Episode Data :  -4.976415222581292
# Batch 866 Q-Learning Episode Data :  -5.921238625468081
# Batch 867 Q-Learning Episode Data :  -4.821462188333943
# Batch 868 Q-Learning Episode Data :  -5.490314493013878
# Batch 869 Q-Learning Episode Data :  -5.186403575912453
# Batch 870 Q-Learning Episode Data :  -5.344379836488232
# Batch 871 Q-Learning Episode Data :  -4.826960389223245
# Batch 872 Q-Learning Episode Data :  -5.47301943391904
# Batch 873 Q-Learning Episode Data :  -4.523660319725743
# Batch 874 Q-Learning Episode Data :  -4.56348914736778
# Batch 875 Q-Learning Episode Data :  -5.341036572062456
# Batch 876 Q-Learning Episode Data :  -5.07076781896175
# Batch 877 Q-Learning Episode Data :  -5.010273341855955
# Batch 878 Q-Learning Episode Data :  -4.499071116324169
# Batch 879 Q-Learning Episode Data :  -4.937890404380242
# Batch 880 Q-Learning Episode Data :  -5.684860788026765
# Batch 881 Q-Learning Episode Data :  -5.509133330554432
# Batch 882 Q-Learning Episode Data :  -5.51145853565961
# Batch 883 Q-Learning Episode Data :  -5.394108430139266
# Batch 884 Q-Learning Episode Data :  -5.4485058976955285
# Batch 885 Q-Learning Episode Data :  -5.303972367929027
# Batch 886 Q-Learning Episode Data :  -4.38969500375225
# Batch 887 Q-Learning Episode Data :  -4.456498564723019
# Batch 888 Q-Learning Episode Data :  -4.788891899724477
# Batch 889 Q-Learning Episode Data :  -5.149386771939466
# Batch 890 Q-Learning Episode Data :  -4.915106978292014
# Batch 891 Q-Learning Episode Data :  -5.086194697256339
# Batch 892 Q-Learning Episode Data :  -4.789568984327377
# Batch 893 Q-Learning Episode Data :  -4.87289447631669
# Batch 894 Q-Learning Episode Data :  -4.644875490160381
# Batch 895 Q-Learning Episode Data :  -5.302322680746874
# Batch 896 Q-Learning Episode Data :  -4.568015235751971
# Batch 897 Q-Learning Episode Data :  -5.311350750696329
# Batch 898 Q-Learning Episode Data :  -5.497467191876512
# Batch 899 Q-Learning Episode Data :  -4.2192859607596365
# Batch 900 Q-Learning Episode Data :  -5.620129844627332
# Batch 901 Q-Learning Episode Data :  -4.807688261212937
# Batch 902 Q-Learning Episode Data :  -3.716195515615313
# Batch 903 Q-Learning Episode Data :  -4.9384421738674655
# Batch 904 Q-Learning Episode Data :  -4.7981584827314485
# Batch 905 Q-Learning Episode Data :  -5.293717398468479
# Batch 906 Q-Learning Episode Data :  -5.151529238253506
# Batch 907 Q-Learning Episode Data :  -4.73482101080359
# Batch 908 Q-Learning Episode Data :  -4.889315063870891
# Batch 909 Q-Learning Episode Data :  -4.809250135976975
# Batch 910 Q-Learning Episode Data :  -5.211529087798497
# Batch 911 Q-Learning Episode Data :  -5.346616612045748
# Batch 912 Q-Learning Episode Data :  -5.6897530087683155
# Batch 913 Q-Learning Episode Data :  -4.763013735064252
# Batch 914 Q-Learning Episode Data :  -5.084587171618302
# Batch 915 Q-Learning Episode Data :  -5.234408728926242
# Batch 916 Q-Learning Episode Data :  -4.800852301307916
# Batch 917 Q-Learning Episode Data :  -5.071167703912176
# Batch 918 Q-Learning Episode Data :  -5.235873689475966
# Batch 919 Q-Learning Episode Data :  -4.661384613878318
# Batch 920 Q-Learning Episode Data :  -5.217551594270754
# Batch 921 Q-Learning Episode Data :  -5.419614336533585
# Batch 922 Q-Learning Episode Data :  -5.014005903725042
# Batch 923 Q-Learning Episode Data :  -5.050272706077066
# Batch 924 Q-Learning Episode Data :  -5.2556963934932215
# Batch 925 Q-Learning Episode Data :  -5.283974496800427
# Batch 926 Q-Learning Episode Data :  -4.796301412605574
# Batch 927 Q-Learning Episode Data :  -4.595726391366282
# Batch 928 Q-Learning Episode Data :  -5.445896718685734
# Batch 929 Q-Learning Episode Data :  -4.632736204035523
# Batch 930 Q-Learning Episode Data :  -6.064517789179307
# Batch 931 Q-Learning Episode Data :  -4.524689554103717
# Batch 932 Q-Learning Episode Data :  -5.365091532557886
# Batch 933 Q-Learning Episode Data :  -4.3541169806151565
# Batch 934 Q-Learning Episode Data :  -5.2326797842109825
# Batch 935 Q-Learning Episode Data :  -5.307254764093085
# Batch 936 Q-Learning Episode Data :  -4.95717395400176
# Batch 937 Q-Learning Episode Data :  -4.7459826195594275
# Batch 938 Q-Learning Episode Data :  -4.963537466557252
# Batch 939 Q-Learning Episode Data :  -4.711884606124278
# Batch 940 Q-Learning Episode Data :  -4.411050906672531
# Batch 941 Q-Learning Episode Data :  -4.622529932292574
# Batch 942 Q-Learning Episode Data :  -4.66276528608366
# Batch 943 Q-Learning Episode Data :  -4.371136019734154
# Batch 944 Q-Learning Episode Data :  -6.269867349596189
# Batch 945 Q-Learning Episode Data :  -5.53588565495337
# Batch 946 Q-Learning Episode Data :  -4.466656318767644
# Batch 947 Q-Learning Episode Data :  -4.765236453546429
# Batch 948 Q-Learning Episode Data :  -5.1486754492251965
# Batch 949 Q-Learning Episode Data :  -5.224817347806371
# Batch 950 Q-Learning Episode Data :  -5.108525967016359
# Batch 951 Q-Learning Episode Data :  -5.585219686783109
# Batch 952 Q-Learning Episode Data :  -5.20223008835173
# Batch 953 Q-Learning Episode Data :  -5.445886904359206
# Batch 954 Q-Learning Episode Data :  -4.8208708345669855
# Batch 955 Q-Learning Episode Data :  -4.957663760446495
# Batch 956 Q-Learning Episode Data :  -5.628251138284679
# Batch 957 Q-Learning Episode Data :  -4.873721790754546
# Batch 958 Q-Learning Episode Data :  -5.604024302639225
# Batch 959 Q-Learning Episode Data :  -4.642696481323874
# Batch 960 Q-Learning Episode Data :  -5.0390309604859365
# Batch 961 Q-Learning Episode Data :  -4.870666268629748
# Batch 962 Q-Learning Episode Data :  -5.109997636713887
# Batch 963 Q-Learning Episode Data :  -4.80288696431304
# Batch 964 Q-Learning Episode Data :  -5.019815895049463
# Batch 965 Q-Learning Episode Data :  -5.445634829418459
# Batch 966 Q-Learning Episode Data :  -5.071178621074186
# Batch 967 Q-Learning Episode Data :  -5.635689869087185
# Batch 968 Q-Learning Episode Data :  -5.204079795168672
# Batch 969 Q-Learning Episode Data :  -4.90786876947502
# Batch 970 Q-Learning Episode Data :  -4.894951326432204
# Batch 971 Q-Learning Episode Data :  -3.9934947906456184
# Batch 972 Q-Learning Episode Data :  -4.774442187269139
# Batch 973 Q-Learning Episode Data :  -4.777532635898939
# Batch 974 Q-Learning Episode Data :  -5.466130442181242
# Batch 975 Q-Learning Episode Data :  -5.058559637840901
# Batch 976 Q-Learning Episode Data :  -5.0794597106835
# Batch 977 Q-Learning Episode Data :  -5.465653554056191
# Batch 978 Q-Learning Episode Data :  -5.167465916093817
# Batch 979 Q-Learning Episode Data :  -5.129303279688385
# Batch 980 Q-Learning Episode Data :  -5.4115238567362045
# Batch 981 Q-Learning Episode Data :  -5.5507859103442
# Batch 982 Q-Learning Episode Data :  -4.7105620861266955
# Batch 983 Q-Learning Episode Data :  -4.67535259385713
# Batch 984 Q-Learning Episode Data :  -4.659479962850911
# Batch 985 Q-Learning Episode Data :  -4.700530258841157
# Batch 986 Q-Learning Episode Data :  -5.07355544847445
# Batch 987 Q-Learning Episode Data :  -5.16415435374312
# Batch 988 Q-Learning Episode Data :  -4.063014213856314
# Batch 989 Q-Learning Episode Data :  -4.54050764102159
# Batch 990 Q-Learning Episode Data :  -5.828101821139878
# Batch 991 Q-Learning Episode Data :  -5.713341594008839
# Batch 992 Q-Learning Episode Data :  -4.817799989216088
# Batch 993 Q-Learning Episode Data :  -5.24060957101181
# Batch 994 Q-Learning Episode Data :  -5.081267122735549
# Batch 995 Q-Learning Episode Data :  -5.146135368087043
# Batch 996 Q-Learning Episode Data :  -5.5535604340661475
# Batch 997 Q-Learning Episode Data :  -4.610728271081782
# Batch 998 Q-Learning Episode Data :  -5.068680262362413
# Batch 999 Q-Learning Episode Data :  -5.579952733920533
# Batch 1000 Q-Learning Episode Data :  -4.535272227925407

# %% [markdown]
# ### c. tables

# %%
df_sarsa.to_csv('df_sarsa_env01.csv', index=False)
df_q_learning.to_csv('df_q_learning_env01.csv', index=False)
