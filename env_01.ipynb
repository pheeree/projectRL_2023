# %% [markdown]
# <a href="https://colab.research.google.com/github/pheeree/projectRL_2023/blob/main/%08env_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Install GYM by OpenAI

# %%
pip install gym
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym) (0.0.8)

# %% [markdown]
# # 2. Import Library

# %%
import gym
from gym import spaces
import numpy as np
import random
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # 3. Modeling RL
# ## (1) Set Env.
#
# 배치로 부터 나온 리워드를 바탕으로 다음 환경의 리워드에 제한을 추가하는 동적 환경을 구성한고 액션에 따른 리워드를 설정함

# %%
# 동적 환경 클래스 정의 - 2
class DynamicEnv(gym.Env):
    def __init__(self):
        super(DynamicEnv, self).__init__()
        self.observation_space = spaces.Discrete(4)  # 네 개의 상태 (0, 1, 2, 3)
        self.action_space = spaces.Discrete(2)  # 두 가지 선택 (0: 현상유지, 1: 변화)
        self.stage = 0
        self.action_prob = 0.3 # 초기 '1' 선택 확률
        self.reward_scale = 1.0  # 보상 스케일 (1을 선택할 때의 보상 크기)

    def step(self, action):
        reward = 0
        done = False

        # 마지막 스테이지 포함 모든 스테이지에서 같은 보상 체계 적용
        if action == 1:
            reward = (10 / self.reward_scale) if random.random() < self.action_prob else (-10 + self.reward_scale)
        else:
            reward = (5 / self.reward_scale) if random.random() < (1 - self.action_prob) else (-5 + self.reward_scale)

        self.stage += 1

        if self.stage == 3:  # 스테이지 3에서는 항상 종료
            done = True

        return self.stage, reward, done, {}

    def reset(self):
        self.stage = 0
        return self.stage

    def update_reward_scale(self, total_reward_batch):
        # 리워드 스케일을 이전 배치의 총 보상에 따라 조정
        self.reward_scale = np.sqrt(abs(total_reward_batch / batch_size)) # 적절한 범위 내에서 조정

# %% [markdown]
# ## (2) Set Agent

# %%
# 에이전트 클래스 정의
class ReinforcementAgent:
    def __init__(self, action_space, state_space, learning_rate=0.1, gamma=0.9, epsilon=0.1):
        self.action_space = action_space
        self.state_space = state_space
        self.learning_rate = learning_rate
        self.gamma = gamma
        self.epsilon = epsilon
        self.Q = np.zeros((state_space, action_space))
        self.recent_reward = 0

    def choose_action(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.randint(0, self.action_space - 1)
        else:
            if self.recent_reward > 0:
                # 양수 보상일 때 랜덤 확률로 액션 0 선택 강화
                return 0 if random.uniform(0.4, 1) > 0.4 else 1
            elif self.recent_reward < 0:
                # 음수 보상일 때 랜덤 확률로 액션 1 선택 강화
                return 1 if random.uniform(0.4, 1) > 0.4 else 0
            else:
                return random.randint(0, self.action_space - 1)

    def learn_sarsa(self, state, action, reward, next_state, next_action):
        predict = self.Q[state, action]
        target = reward + self.gamma * self.Q[next_state, next_action]
        self.Q[state, action] += self.learning_rate * (target - predict)

    def learn_q_learning(self, state, action, reward, next_state):
        predict = self.Q[state, action]
        target = reward + self.gamma * np.max(self.Q[next_state, :])
        self.Q[state, action] += self.learning_rate * (target - predict)

# %% [markdown]
# ## (3) 학습
# ### a. SARSA

# %%
# 환경 및 에이전트 초기화
env = DynamicEnv()
agent = ReinforcementAgent(env.action_space.n, env.observation_space.n)

# 배치 학습 설정 및 실행
num_batches = 1000
batch_size = 1000

for batch in range(num_batches):
    episode_data_sarsa = []
    total_reward_batch = 0

    for episode in range(batch_size):
        state = env.reset()
        episode_reward_sarsa = 0
        episode_actions_sarsa = []
        episode_rewards_sarsa = []  # 각 스테이지별 보상을 저장하기 위한 리스트

        # SARSA 학습
        while True:
            action = agent.choose_action(state)
            episode_actions_sarsa.append(action)
            next_state, reward, done, _ = env.step(action)
            episode_rewards_sarsa.append(reward)  # 스테이지별 보상 추가
            episode_reward_sarsa += reward
            agent.recent_reward = reward
            next_action = agent.choose_action(next_state)
            agent.learn_sarsa(state, action, reward, next_state, next_action)
            state = next_state
            if done:
                break

        episode_data_sarsa.append({
            'Episode': episode + 1,
            'Stage Rewards': episode_rewards_sarsa,
            'Total Reward': episode_reward_sarsa
        })

        total_reward_batch += episode_reward_sarsa

    env.update_reward_scale(total_reward_batch)


    # 데이터 프레임 생성
    df_sarsa = pd.DataFrame(episode_data_sarsa)
    #print(f"Batch {batch + 1} SARSA Episode Data:")
    #print(df_sarsa)
    print(f"Batch {batch + 1} Total Average Reward: {total_reward_batch / batch_size}")

    # 에피소드별 총 보상을 기준으로 데이터 프레임 정렬
    df_sorted = df_sarsa.sort_values(by='Total Reward', ascending=False)

    # 상위 10% 에피소드의 평균 점수 계산
    top_10_avg_reward = df_sorted['Total Reward'].head(int(batch_size*0.1)).mean()

    #print(f"Batch {batch + 1} Top 100 Episodes Average Reward: {top_10_avg_reward}")
# Out:
# Batch 1 Total Average Reward: -1.989
# Batch 2 Total Average Reward: -3.222800445826314
# Batch 3 Total Average Reward: -5.6909265060547884
# Batch 4 Total Average Reward: -5.582436047451774
# Batch 5 Total Average Reward: -4.989259680892446
# Batch 6 Total Average Reward: -4.909020597763859
# Batch 7 Total Average Reward: -4.903057153585538
# Batch 8 Total Average Reward: -5.128276072826024
# Batch 9 Total Average Reward: -5.199917387417043
# Batch 10 Total Average Reward: -5.625386842523115
# Batch 11 Total Average Reward: -5.498090397777181
# Batch 12 Total Average Reward: -5.587358960370357
# Batch 13 Total Average Reward: -4.860828339360243
# Batch 14 Total Average Reward: -4.0360757296377425
# Batch 15 Total Average Reward: -4.594311544353176
# Batch 16 Total Average Reward: -5.085391203906622
# Batch 17 Total Average Reward: -5.351435306219852
# Batch 18 Total Average Reward: -5.388217863276161
# Batch 19 Total Average Reward: -5.086620392052284
# Batch 20 Total Average Reward: -5.462866438946682
# Batch 21 Total Average Reward: -5.596728468607505
# Batch 22 Total Average Reward: -5.627476727849022
# Batch 23 Total Average Reward: -5.50162952586659
# Batch 976 Total Average Reward: -5.289107145539631
# Batch 977 Total Average Reward: -5.473977593734034
# Batch 978 Total Average Reward: -5.527722201928792
# Batch 979 Total Average Reward: -5.79953019645716
# Batch 980 Total Average Reward: -5.576179031538608
# Batch 981 Total Average Reward: -5.2052667116949305
# Batch 982 Total Average Reward: -5.111966221315737
# Batch 983 Total Average Reward: -4.697343502760415
# Batch 984 Total Average Reward: -4.430343903171963
# Batch 985 Total Average Reward: -4.710298476445377
# Batch 986 Total Average Reward: -5.2958258278011545
# Batch 987 Total Average Reward: -5.446967482039188
# Batch 988 Total Average Reward: -5.826279566935423
# Batch 989 Total Average Reward: -4.605045487401674
# Batch 990 Total Average Reward: -5.089720365680014
# Batch 991 Total Average Reward: -5.845854098368421
# Batch 992 Total Average Reward: -4.65334708255879
# Batch 993 Total Average Reward: -6.0262599208233585
# Batch 994 Total Average Reward: -5.329730699247359
# Batch 995 Total Average Reward: -4.815605243660821
# Batch 996 Total Average Reward: -4.73172050268642
# Batch 997 Total Average Reward: -5.2038421773151455
# Batch 998 Total Average Reward: -5.32320464970773
# Batch 999 Total Average Reward: -5.758534461967141
# Batch 1000 Total Average Reward: -4.5277092460747985

# %% [markdown]
# ### b. Q-Learning

# %%
# 환경 및 에이전트 초기화
env = DynamicEnv()
agent = ReinforcementAgent(env.action_space.n, env.observation_space.n)

# 배치 학습 설정
num_batches = 1000
batch_size = 1000

for batch in range(num_batches):
    episode_data_q_learning = []
    total_reward_batch = 0

    for episode in range(batch_size):
        state = env.reset()
        episode_reward_q_learning = 0
        episode_actions_q_learning = []
        episode_rewards_q_learning = []  # 각 스테이지별 보상을 저장하기 위한 리스트

        # Q-Learning 학습
        while True:
            action = agent.choose_action(state)
            episode_actions_q_learning.append(action)
            next_state, reward, done, _ = env.step(action)
            episode_rewards_q_learning.append(reward)  # 스테이지별 보상 추가
            episode_reward_q_learning += reward
            agent.recent_reward = reward
            agent.learn_q_learning(state, action, reward, next_state)
            state = next_state
            if done:
                break

        episode_data_q_learning.append({
            'Episode': episode + 1,
            'Stage Rewards': episode_rewards_q_learning,
            'Total Reward': episode_reward_q_learning
        })

        total_reward_batch += episode_reward_q_learning

    env.update_reward_scale(total_reward_batch)

    # Q-Learning 결과 처리
    df_q_learning = pd.DataFrame(episode_data_q_learning)
    batch_avg_reward_q_learning = df_q_learning['Total Reward'].mean()
    #print(f"Batch {batch + 1} Q-Learning Episode Data")
    #print(df_q_learning)
    print(f"Batch {batch + 1} Q-Learning Episode Data : ", total_reward_batch / batch_size)

    # 에피소드별 총 보상을 기준으로 데이터 프레임 정렬
    df_sorted_Q = df_q_learning.sort_values(by='Total Reward', ascending=False)

    # 상위 10% 에피소드의 평균 점수 계산
    top_10_avg_reward_Q = df_sorted_Q['Total Reward'].head(int(batch_size*0.1)).mean()

    #print(f"Batch {batch + 1} Top 100 Episodes Average Reward: {top_10_avg_reward_Q}")
# Out:
# Batch 1 Q-Learning Episode Data :  -1.039
# Batch 2 Q-Learning Episode Data :  -1.5273807525317016
# Batch 3 Q-Learning Episode Data :  -1.9436944051285692
# Batch 4 Q-Learning Episode Data :  -3.9043170113931884
# Batch 5 Q-Learning Episode Data :  -4.946158770757858
# Batch 6 Q-Learning Episode Data :  -4.991855066033644
# Batch 7 Q-Learning Episode Data :  -4.952323438260949
# Batch 8 Q-Learning Episode Data :  -5.2515131268867385
# Batch 9 Q-Learning Episode Data :  -4.9489027293604675
# Batch 10 Q-Learning Episode Data :  -4.902797870630731
# Batch 11 Q-Learning Episode Data :  -5.032750286557678
# Batch 12 Q-Learning Episode Data :  -5.236098136141035
# Batch 13 Q-Learning Episode Data :  -5.03266711823636
# Batch 14 Q-Learning Episode Data :  -5.611930771713228
# Batch 15 Q-Learning Episode Data :  -5.465229452551163
# Batch 16 Q-Learning Episode Data :  -5.472158622241056
# Batch 17 Q-Learning Episode Data :  -4.789376835454167
# Batch 18 Q-Learning Episode Data :  -5.117322235334748
# Batch 19 Q-Learning Episode Data :  -4.957522840135163
# Batch 20 Q-Learning Episode Data :  -4.670248162426072
# Batch 21 Q-Learning Episode Data :  -4.991099078663445
# Batch 22 Q-Learning Episode Data :  -4.999618170112649
# Batch 23 Q-Learning Episode Data :  -5.044998844069498
# Batch 24 Q-Learning Episode Data :  -5.241881245624273
# Batch 25 Q-Learning Episode Data :  -4.541833945385457
# Batch 26 Q-Learning Episode Data :  -5.635005965310218
# Batch 27 Q-Learning Episode Data :  -4.5329468676385085
# Batch 28 Q-Learning Episode Data :  -4.698357388017577
# Batch 29 Q-Learning Episode Data :  -5.785215062607205
# Batch 30 Q-Learning Episode Data :  -5.290626958351954
# Batch 31 Q-Learning Episode Data :  -4.786558487473969
# Batch 32 Q-Learning Episode Data :  -6.187867170959382
# Batch 33 Q-Learning Episode Data :  -4.18080017596755
# Batch 34 Q-Learning Episode Data :  -4.71571054004187
# Batch 35 Q-Learning Episode Data :  -5.364032670571285
# Batch 36 Q-Learning Episode Data :  -5.407350094959575
# Batch 37 Q-Learning Episode Data :  -5.60000853662488
# Batch 38 Q-Learning Episode Data :  -5.359528133146237
# Batch 39 Q-Learning Episode Data :  -4.958638619620619
# Batch 40 Q-Learning Episode Data :  -5.78884273439462
# Batch 41 Q-Learning Episode Data :  -5.042426149239681
# Batch 42 Q-Learning Episode Data :  -5.079596535975376
# Batch 43 Q-Learning Episode Data :  -5.243800141264259
# Batch 44 Q-Learning Episode Data :  -4.524131179561494
# Batch 45 Q-Learning Episode Data :  -5.391880168553845
# Batch 46 Q-Learning Episode Data :  -5.000163122041225
# Batch 47 Q-Learning Episode Data :  -5.7728125963817
# Batch 48 Q-Learning Episode Data :  -4.203193055896654
# Batch 49 Q-Learning Episode Data :  -5.1369425973152305
# Batch 50 Q-Learning Episode Data :  -4.564259872988208
# Batch 51 Q-Learning Episode Data :  -5.183251378732085
# Batch 52 Q-Learning Episode Data :  -5.3079103558340135
# Batch 53 Q-Learning Episode Data :  -4.506169775157928
# Batch 54 Q-Learning Episode Data :  -4.616496816630245
# Batch 55 Q-Learning Episode Data :  -4.818890943619502
# Batch 56 Q-Learning Episode Data :  -4.111670438689445
# Batch 57 Q-Learning Episode Data :  -4.676273136260305
# Batch 58 Q-Learning Episode Data :  -5.197345137934244
# Batch 59 Q-Learning Episode Data :  -5.406878367219152
# Batch 60 Q-Learning Episode Data :  -5.394255391153789
# Batch 61 Q-Learning Episode Data :  -5.196630401430099
# Batch 62 Q-Learning Episode Data :  -4.746029225334998
# Batch 63 Q-Learning Episode Data :  -4.68590906944432
# Batch 64 Q-Learning Episode Data :  -4.8224317469939315
# Batch 65 Q-Learning Episode Data :  -5.599957064159089
# Batch 66 Q-Learning Episode Data :  -5.3330774414941535
# Batch 67 Q-Learning Episode Data :  -5.243464172823604
# Batch 68 Q-Learning Episode Data :  -5.748788229665588
# Batch 69 Q-Learning Episode Data :  -5.03515821493414
# Batch 70 Q-Learning Episode Data :  -5.105751120437511
# Batch 71 Q-Learning Episode Data :  -4.758094463753805
# Batch 72 Q-Learning Episode Data :  -4.399690492480061
# Batch 73 Q-Learning Episode Data :  -5.246137118103791
# Batch 74 Q-Learning Episode Data :  -5.509144830997943
# Batch 75 Q-Learning Episode Data :  -5.228469585324054
# Batch 76 Q-Learning Episode Data :  -5.090582929790705
# Batch 77 Q-Learning Episode Data :  -5.031584273325486
# Batch 78 Q-Learning Episode Data :  -5.433791729757898
# Batch 79 Q-Learning Episode Data :  -5.055775081920523
# Batch 80 Q-Learning Episode Data :  -5.169661473663774
# Batch 81 Q-Learning Episode Data :  -5.873261683538248
# Batch 82 Q-Learning Episode Data :  -4.969739636774982
# Batch 83 Q-Learning Episode Data :  -4.803998411407735
# Batch 84 Q-Learning Episode Data :  -4.687367469284867
# Batch 85 Q-Learning Episode Data :  -5.4305302818116035
# Batch 86 Q-Learning Episode Data :  -4.804438459446977
# Batch 87 Q-Learning Episode Data :  -5.371225018481984
# Batch 88 Q-Learning Episode Data :  -4.5984574328399335
# Batch 89 Q-Learning Episode Data :  -4.6921804832001355
# Batch 90 Q-Learning Episode Data :  -4.984385738051697
# Batch 91 Q-Learning Episode Data :  -4.7794123751008435
# Batch 92 Q-Learning Episode Data :  -5.193879147227722
# Batch 93 Q-Learning Episode Data :  -5.193445913266532
# Batch 94 Q-Learning Episode Data :  -5.530782702947405
# Batch 95 Q-Learning Episode Data :  -5.288468250556839
# Batch 96 Q-Learning Episode Data :  -4.995525451162141
# Batch 97 Q-Learning Episode Data :  -4.366041861057014
# Batch 98 Q-Learning Episode Data :  -4.724908063008965
# Batch 99 Q-Learning Episode Data :  -4.84097468217875
# Batch 100 Q-Learning Episode Data :  -4.988255564880888
# Batch 101 Q-Learning Episode Data :  -5.394250878952523
# Batch 102 Q-Learning Episode Data :  -5.364269039837036
# Batch 103 Q-Learning Episode Data :  -5.409768161513603
# Batch 104 Q-Learning Episode Data :  -5.192899832142894
# Batch 105 Q-Learning Episode Data :  -5.2810085757690866
# Batch 106 Q-Learning Episode Data :  -5.147635599397171
# Batch 107 Q-Learning Episode Data :  -5.378968464218126
# Batch 108 Q-Learning Episode Data :  -5.14263548516039
# Batch 109 Q-Learning Episode Data :  -4.784715689726554
# Batch 110 Q-Learning Episode Data :  -5.00191039057303
# Batch 111 Q-Learning Episode Data :  -5.034328392211394
# Batch 112 Q-Learning Episode Data :  -4.724492934921472
# Batch 113 Q-Learning Episode Data :  -5.194493997156568
# Batch 114 Q-Learning Episode Data :  -4.897960634285983
# Batch 115 Q-Learning Episode Data :  -5.347967776888815
# Batch 116 Q-Learning Episode Data :  -5.41354042887097
# Batch 117 Q-Learning Episode Data :  -4.791929425064719
# Batch 118 Q-Learning Episode Data :  -5.467784433806793
# Batch 119 Q-Learning Episode Data :  -5.042737286519297
# Batch 120 Q-Learning Episode Data :  -5.454909147348918
# Batch 121 Q-Learning Episode Data :  -5.469156338769397
# Batch 122 Q-Learning Episode Data :  -5.54444208147753
# Batch 123 Q-Learning Episode Data :  -4.720219004469946
# Batch 124 Q-Learning Episode Data :  -5.362294802914036
# Batch 125 Q-Learning Episode Data :  -5.148704376087924
# Batch 126 Q-Learning Episode Data :  -5.196966219069266
# Batch 127 Q-Learning Episode Data :  -5.240691399678135
# Batch 128 Q-Learning Episode Data :  -5.816466481247313
# Batch 129 Q-Learning Episode Data :  -5.832239947213597
# Batch 130 Q-Learning Episode Data :  -5.328319987794106
# Batch 131 Q-Learning Episode Data :  -5.001686853722819
# Batch 132 Q-Learning Episode Data :  -5.544391656441636
# Batch 133 Q-Learning Episode Data :  -5.05040760758568
# Batch 134 Q-Learning Episode Data :  -5.024178547838095
# Batch 135 Q-Learning Episode Data :  -5.013100158849527
# Batch 136 Q-Learning Episode Data :  -4.43013249642374
# Batch 137 Q-Learning Episode Data :  -4.453552633281589
# Batch 138 Q-Learning Episode Data :  -4.94147077940855
# Batch 139 Q-Learning Episode Data :  -5.488252390039552
# Batch 140 Q-Learning Episode Data :  -4.812532721908468
# Batch 141 Q-Learning Episode Data :  -5.380028713685046
# Batch 142 Q-Learning Episode Data :  -4.570576980448279
# Batch 143 Q-Learning Episode Data :  -4.893167472005508
# Batch 144 Q-Learning Episode Data :  -4.667031162390335
# Batch 145 Q-Learning Episode Data :  -5.317005802247869
# Batch 146 Q-Learning Episode Data :  -5.125791631210136
# Batch 147 Q-Learning Episode Data :  -4.6388456895664465
# Batch 148 Q-Learning Episode Data :  -5.331833663356056
# Batch 149 Q-Learning Episode Data :  -5.473155708903686
# Batch 150 Q-Learning Episode Data :  -4.78778548708047
# Batch 151 Q-Learning Episode Data :  -5.550496139164133
# Batch 152 Q-Learning Episode Data :  -4.899431559507179
# Batch 153 Q-Learning Episode Data :  -5.201256613476281
# Batch 154 Q-Learning Episode Data :  -5.132944587811154
# Batch 155 Q-Learning Episode Data :  -4.940879455223629
# Batch 156 Q-Learning Episode Data :  -5.423530406691285
# Batch 157 Q-Learning Episode Data :  -4.834875351016503
# Batch 158 Q-Learning Episode Data :  -5.399697170441926
# Batch 159 Q-Learning Episode Data :  -5.502142359501219
# Batch 160 Q-Learning Episode Data :  -4.857744666182798
# Batch 161 Q-Learning Episode Data :  -5.302604351589387
# Batch 162 Q-Learning Episode Data :  -5.629763799790835
# Batch 163 Q-Learning Episode Data :  -5.00798831863047
# Batch 164 Q-Learning Episode Data :  -5.6518969821246765
# Batch 165 Q-Learning Episode Data :  -5.5033575277268065
# Batch 166 Q-Learning Episode Data :  -5.273586803408037
# Batch 167 Q-Learning Episode Data :  -5.208664198677887
# Batch 168 Q-Learning Episode Data :  -4.411234176891401
# Batch 169 Q-Learning Episode Data :  -5.136736107675135
# Batch 170 Q-Learning Episode Data :  -4.755437759801635
# Batch 171 Q-Learning Episode Data :  -5.215860178289043
# Batch 172 Q-Learning Episode Data :  -5.16005753385828
# Batch 173 Q-Learning Episode Data :  -4.907901880155125
# Batch 174 Q-Learning Episode Data :  -5.125029422390938
# Batch 175 Q-Learning Episode Data :  -5.202310842026704
# Batch 176 Q-Learning Episode Data :  -5.811998397719349
# Batch 177 Q-Learning Episode Data :  -4.897419285837139
# Batch 178 Q-Learning Episode Data :  -4.922389119793669
# Batch 179 Q-Learning Episode Data :  -4.988263711261794
# Batch 180 Q-Learning Episode Data :  -4.638427301777973
# Batch 181 Q-Learning Episode Data :  -4.084475969851281
# Batch 182 Q-Learning Episode Data :  -5.139132644068236
# Batch 183 Q-Learning Episode Data :  -5.232859852834245
# Batch 184 Q-Learning Episode Data :  -5.147801876851297
# Batch 185 Q-Learning Episode Data :  -5.651774957302887
# Batch 186 Q-Learning Episode Data :  -5.08200424539902
# Batch 187 Q-Learning Episode Data :  -4.8248249892719794
# Batch 188 Q-Learning Episode Data :  -5.221001792702237
# Batch 189 Q-Learning Episode Data :  -5.634053641139934
# Batch 190 Q-Learning Episode Data :  -4.743403796768713
# Batch 191 Q-Learning Episode Data :  -5.073919355051454
# Batch 192 Q-Learning Episode Data :  -5.134183071800143
# Batch 193 Q-Learning Episode Data :  -5.473772361714049
# Batch 194 Q-Learning Episode Data :  -5.1511243126876725
# Batch 195 Q-Learning Episode Data :  -4.553916205228884
# Batch 196 Q-Learning Episode Data :  -4.682394141109181
# Batch 197 Q-Learning Episode Data :  -5.904433146908656
# Batch 198 Q-Learning Episode Data :  -5.855020646916014
# Batch 199 Q-Learning Episode Data :  -5.4574922637113215
# Batch 200 Q-Learning Episode Data :  -5.2312840814615225
# Batch 201 Q-Learning Episode Data :  -5.0772173796849005
# Batch 202 Q-Learning Episode Data :  -4.197046873211291
# Batch 203 Q-Learning Episode Data :  -4.966930757514437
# Batch 204 Q-Learning Episode Data :  -5.355253932167971
# Batch 205 Q-Learning Episode Data :  -4.570646115956525
# Batch 206 Q-Learning Episode Data :  -5.285298055141392
# Batch 207 Q-Learning Episode Data :  -4.243408217133249
# Batch 208 Q-Learning Episode Data :  -4.261508020533097
# Batch 209 Q-Learning Episode Data :  -5.256614376479449
# Batch 210 Q-Learning Episode Data :  -4.920731851335829
# Batch 211 Q-Learning Episode Data :  -4.093142146207269
# Batch 212 Q-Learning Episode Data :  -5.63721888920527
# Batch 213 Q-Learning Episode Data :  -5.40269608685205
# Batch 214 Q-Learning Episode Data :  -5.67483267126364
# Batch 215 Q-Learning Episode Data :  -4.9450017690884245
# Batch 216 Q-Learning Episode Data :  -4.655438463824426
# Batch 217 Q-Learning Episode Data :  -4.993930935788999
# Batch 218 Q-Learning Episode Data :  -4.958497623150298
# Batch 219 Q-Learning Episode Data :  -4.919136415063694
# Batch 220 Q-Learning Episode Data :  -5.579634092439596
# Batch 221 Q-Learning Episode Data :  -4.907483476076586
# Batch 222 Q-Learning Episode Data :  -4.982854593094889
# Batch 223 Q-Learning Episode Data :  -4.602695451842072
# Batch 224 Q-Learning Episode Data :  -5.7718612295985565
# Batch 225 Q-Learning Episode Data :  -4.561717777761471
# Batch 226 Q-Learning Episode Data :  -4.758398208435522
# Batch 227 Q-Learning Episode Data :  -4.490992419460922
# Batch 228 Q-Learning Episode Data :  -4.834202271097787
# Batch 229 Q-Learning Episode Data :  -4.335975860083516
# Batch 230 Q-Learning Episode Data :  -5.235889413143217
# Batch 231 Q-Learning Episode Data :  -4.915417995269249
# Batch 232 Q-Learning Episode Data :  -4.729846191980232
# Batch 233 Q-Learning Episode Data :  -4.620115064333972
# Batch 234 Q-Learning Episode Data :  -5.702679769839059
# Batch 235 Q-Learning Episode Data :  -5.498698927712876
# Batch 236 Q-Learning Episode Data :  -5.219688614940123
# Batch 237 Q-Learning Episode Data :  -5.147541380243512
# Batch 238 Q-Learning Episode Data :  -5.018290558317023
# Batch 239 Q-Learning Episode Data :  -4.929320554248775
# Batch 240 Q-Learning Episode Data :  -5.1270833711540575
# Batch 241 Q-Learning Episode Data :  -4.671534083241951
# Batch 242 Q-Learning Episode Data :  -4.6176689845033705
# Batch 243 Q-Learning Episode Data :  -5.747554473993625
# Batch 244 Q-Learning Episode Data :  -4.666108131348239
# Batch 245 Q-Learning Episode Data :  -4.964295742444985
# Batch 246 Q-Learning Episode Data :  -4.838882058472374
# Batch 247 Q-Learning Episode Data :  -5.380722707630478
# Batch 248 Q-Learning Episode Data :  -4.727628832406478
# Batch 249 Q-Learning Episode Data :  -4.572826039249405
# Batch 250 Q-Learning Episode Data :  -5.0272763505968925
# Batch 251 Q-Learning Episode Data :  -5.827455991575571
# Batch 252 Q-Learning Episode Data :  -5.214064709929908
# Batch 253 Q-Learning Episode Data :  -5.18970506696718
# Batch 254 Q-Learning Episode Data :  -5.717995798678842
# Batch 255 Q-Learning Episode Data :  -5.323332325830253
# Batch 256 Q-Learning Episode Data :  -4.782198998548598
# Batch 257 Q-Learning Episode Data :  -5.550118611248737
# Batch 258 Q-Learning Episode Data :  -4.434249688746056
# Batch 259 Q-Learning Episode Data :  -4.94937020816418
# Batch 260 Q-Learning Episode Data :  -4.984248915559216
# Batch 261 Q-Learning Episode Data :  -5.089089562356091
# Batch 262 Q-Learning Episode Data :  -5.8747776599701345
# Batch 263 Q-Learning Episode Data :  -5.3752159815420555
# Batch 264 Q-Learning Episode Data :  -4.652134516127238
# Batch 265 Q-Learning Episode Data :  -5.164866072765598
# Batch 266 Q-Learning Episode Data :  -4.864669056362696
# Batch 267 Q-Learning Episode Data :  -4.363902401923808
# Batch 268 Q-Learning Episode Data :  -3.819745470716961
# Batch 269 Q-Learning Episode Data :  -4.984140236562604
# Batch 270 Q-Learning Episode Data :  -4.140821990560265
# Batch 271 Q-Learning Episode Data :  -5.514644140174377
# Batch 272 Q-Learning Episode Data :  -5.348436498183103
# Batch 273 Q-Learning Episode Data :  -4.828557562604419
# Batch 274 Q-Learning Episode Data :  -4.8152552314893455
# Batch 275 Q-Learning Episode Data :  -5.331919530720137
# Batch 276 Q-Learning Episode Data :  -5.495878859690175
# Batch 277 Q-Learning Episode Data :  -5.768153533775136
# Batch 278 Q-Learning Episode Data :  -5.353714319636892
# Batch 279 Q-Learning Episode Data :  -5.628623546952774
# Batch 280 Q-Learning Episode Data :  -4.8992813190666
# Batch 281 Q-Learning Episode Data :  -4.8931207837759985
# Batch 282 Q-Learning Episode Data :  -4.9958417071045
# Batch 283 Q-Learning Episode Data :  -5.35586101708233
# Batch 284 Q-Learning Episode Data :  -5.457788263907095
# Batch 285 Q-Learning Episode Data :  -5.4063073393722805
# Batch 286 Q-Learning Episode Data :  -5.192179373193762
# Batch 287 Q-Learning Episode Data :  -4.497469815250097
# Batch 288 Q-Learning Episode Data :  -4.87243204618751
# Batch 289 Q-Learning Episode Data :  -5.337846272986096
# Batch 290 Q-Learning Episode Data :  -4.25814741529135
# Batch 291 Q-Learning Episode Data :  -5.070468366305649
# Batch 292 Q-Learning Episode Data :  -5.747928485958008
# Batch 293 Q-Learning Episode Data :  -5.369434101990723
# Batch 294 Q-Learning Episode Data :  -5.1639391961040575
# Batch 295 Q-Learning Episode Data :  -4.456035994668305
# Batch 296 Q-Learning Episode Data :  -4.614379209737701
# Batch 297 Q-Learning Episode Data :  -5.4243044186314
# Batch 298 Q-Learning Episode Data :  -4.930831064702362
# Batch 299 Q-Learning Episode Data :  -4.929672633259623
# Batch 300 Q-Learning Episode Data :  -5.030402066077885
# Batch 301 Q-Learning Episode Data :  -4.4804895884968605
# Batch 302 Q-Learning Episode Data :  -4.784653080561832
# Batch 303 Q-Learning Episode Data :  -4.681901832955673
# Batch 304 Q-Learning Episode Data :  -5.271368650390422
# Batch 305 Q-Learning Episode Data :  -5.59174045921423
# Batch 306 Q-Learning Episode Data :  -3.9775787400105185
# Batch 307 Q-Learning Episode Data :  -4.398097485728948
# Batch 308 Q-Learning Episode Data :  -4.639599499671017
# Batch 309 Q-Learning Episode Data :  -5.1650633779716655
# Batch 310 Q-Learning Episode Data :  -5.133490759027408
# Batch 311 Q-Learning Episode Data :  -4.823122850031445
# Batch 312 Q-Learning Episode Data :  -4.297869032755418
# Batch 313 Q-Learning Episode Data :  -4.8388191342086975
# Batch 314 Q-Learning Episode Data :  -4.882486195310328
# Batch 315 Q-Learning Episode Data :  -4.404289205998003
# Batch 316 Q-Learning Episode Data :  -4.137474177037898
# Batch 317 Q-Learning Episode Data :  -5.200392282669377
# Batch 318 Q-Learning Episode Data :  -5.515947531133146
# Batch 319 Q-Learning Episode Data :  -5.467797969163947
# Batch 320 Q-Learning Episode Data :  -5.37088972972786
# Batch 321 Q-Learning Episode Data :  -4.170456636202391
# Batch 322 Q-Learning Episode Data :  -5.178973842755287
# Batch 323 Q-Learning Episode Data :  -4.995814364223836
# Batch 324 Q-Learning Episode Data :  -4.69260853270578
# Batch 325 Q-Learning Episode Data :  -5.207699171649932
# Batch 326 Q-Learning Episode Data :  -4.7690229226489125
# Batch 327 Q-Learning Episode Data :  -4.815626386181748
# Batch 328 Q-Learning Episode Data :  -5.369040726433321
# Batch 329 Q-Learning Episode Data :  -4.854977163279479
# Batch 330 Q-Learning Episode Data :  -5.894827657209974
# Batch 331 Q-Learning Episode Data :  -4.3368060873273695
# Batch 332 Q-Learning Episode Data :  -5.201867208546203
# Batch 333 Q-Learning Episode Data :  -5.040811831917522
# Batch 334 Q-Learning Episode Data :  -5.158845747506357
# Batch 335 Q-Learning Episode Data :  -5.1560149861585485
# Batch 336 Q-Learning Episode Data :  -4.770935747624989
# Batch 337 Q-Learning Episode Data :  -4.5358976179573425
# Batch 338 Q-Learning Episode Data :  -4.547291968653986
# Batch 339 Q-Learning Episode Data :  -5.10082580540183
# Batch 340 Q-Learning Episode Data :  -4.738460457422895
# Batch 341 Q-Learning Episode Data :  -4.157283082826418
# Batch 342 Q-Learning Episode Data :  -5.4591555907534985
# Batch 343 Q-Learning Episode Data :  -5.035059822298341
# Batch 344 Q-Learning Episode Data :  -4.656281209768151
# Batch 345 Q-Learning Episode Data :  -4.892715859169007
# Batch 346 Q-Learning Episode Data :  -5.674044886501372
# Batch 347 Q-Learning Episode Data :  -5.197675502184078
# Batch 348 Q-Learning Episode Data :  -5.094688810230534
# Batch 349 Q-Learning Episode Data :  -4.749068192739996
# Batch 350 Q-Learning Episode Data :  -5.299017490339552
# Batch 351 Q-Learning Episode Data :  -5.303284992736542
# Batch 352 Q-Learning Episode Data :  -5.269752553343179
# Batch 353 Q-Learning Episode Data :  -5.484709848313487
# Batch 354 Q-Learning Episode Data :  -5.175827110454842
# Batch 355 Q-Learning Episode Data :  -5.198239359122387
# Batch 356 Q-Learning Episode Data :  -4.736456648921137
# Batch 357 Q-Learning Episode Data :  -5.258064164218527
# Batch 358 Q-Learning Episode Data :  -4.789754968398874
# Batch 359 Q-Learning Episode Data :  -4.917984957907508
# Batch 360 Q-Learning Episode Data :  -4.031610577149448
# Batch 361 Q-Learning Episode Data :  -4.713440650970213
# Batch 362 Q-Learning Episode Data :  -4.863093999530334
# Batch 363 Q-Learning Episode Data :  -4.87324733875764
# Batch 364 Q-Learning Episode Data :  -4.708968880506365
# Batch 365 Q-Learning Episode Data :  -4.923847463705885
# Batch 366 Q-Learning Episode Data :  -4.896323680567656
# Batch 367 Q-Learning Episode Data :  -5.1563666345592365
# Batch 368 Q-Learning Episode Data :  -5.154088087988184
# Batch 369 Q-Learning Episode Data :  -4.641592939495187
# Batch 370 Q-Learning Episode Data :  -4.721123675585478
# Batch 371 Q-Learning Episode Data :  -5.184374880185456
# Batch 372 Q-Learning Episode Data :  -5.032271097180899
# Batch 373 Q-Learning Episode Data :  -5.200586002357446
# Batch 374 Q-Learning Episode Data :  -4.593261940468779
# Batch 375 Q-Learning Episode Data :  -5.789301830605427
# Batch 376 Q-Learning Episode Data :  -4.6128032674628745
# Batch 377 Q-Learning Episode Data :  -4.876607508728386
# Batch 378 Q-Learning Episode Data :  -4.353506778546558
# Batch 379 Q-Learning Episode Data :  -5.315787439379098
# Batch 380 Q-Learning Episode Data :  -4.951096214276899
# Batch 381 Q-Learning Episode Data :  -4.294982414750879
# Batch 382 Q-Learning Episode Data :  -5.4932270514383275
# Batch 383 Q-Learning Episode Data :  -5.345638342285379
# Batch 384 Q-Learning Episode Data :  -4.689595220239626
# Batch 385 Q-Learning Episode Data :  -5.212410889012224
# Batch 386 Q-Learning Episode Data :  -4.788653407724021
# Batch 387 Q-Learning Episode Data :  -4.87271030817995
# Batch 388 Q-Learning Episode Data :  -5.1998048407688975
# Batch 389 Q-Learning Episode Data :  -4.558801470194597
# Batch 390 Q-Learning Episode Data :  -5.10077104495878
# Batch 391 Q-Learning Episode Data :  -4.96720525531472
# Batch 392 Q-Learning Episode Data :  -4.741845071860507
# Batch 393 Q-Learning Episode Data :  -4.984267119703277
# Batch 394 Q-Learning Episode Data :  -4.905853804643994
# Batch 395 Q-Learning Episode Data :  -4.821171312199276
# Batch 396 Q-Learning Episode Data :  -5.202828763826777
# Batch 397 Q-Learning Episode Data :  -5.234717152428669
# Batch 398 Q-Learning Episode Data :  -4.5301370899578135
# Batch 399 Q-Learning Episode Data :  -4.885479014021272
# Batch 400 Q-Learning Episode Data :  -3.910652397653632
# Batch 401 Q-Learning Episode Data :  -5.343925420394476
# Batch 402 Q-Learning Episode Data :  -5.270457971428398
# Batch 403 Q-Learning Episode Data :  -4.553153709947974
# Batch 404 Q-Learning Episode Data :  -4.427514684866062
# Batch 405 Q-Learning Episode Data :  -5.238693070598179
# Batch 406 Q-Learning Episode Data :  -5.611165420805993
# Batch 407 Q-Learning Episode Data :  -5.1318145087327975
# Batch 408 Q-Learning Episode Data :  -4.801977316271713
# Batch 409 Q-Learning Episode Data :  -4.638447656302898
# Batch 410 Q-Learning Episode Data :  -4.539945296091488
# Batch 411 Q-Learning Episode Data :  -5.2320608954290035
# Batch 412 Q-Learning Episode Data :  -5.771694728078577
# Batch 413 Q-Learning Episode Data :  -5.004706742133939
# Batch 414 Q-Learning Episode Data :  -4.237523853450078
# Batch 415 Q-Learning Episode Data :  -4.544496969941296
# Batch 416 Q-Learning Episode Data :  -5.141775812805675
# Batch 417 Q-Learning Episode Data :  -5.469307126894874
# Batch 418 Q-Learning Episode Data :  -5.04742308539862
# Batch 419 Q-Learning Episode Data :  -4.662171112820411
# Batch 420 Q-Learning Episode Data :  -5.2519701769913905
# Batch 421 Q-Learning Episode Data :  -5.325363256976212
# Batch 422 Q-Learning Episode Data :  -5.371328806635407
# Batch 423 Q-Learning Episode Data :  -4.8009525168435205
# Batch 424 Q-Learning Episode Data :  -4.996491766813223
# Batch 425 Q-Learning Episode Data :  -5.310630438792228
# Batch 426 Q-Learning Episode Data :  -4.601450027947813
# Batch 427 Q-Learning Episode Data :  -4.604387812412815
# Batch 428 Q-Learning Episode Data :  -4.1829735888447965
# Batch 429 Q-Learning Episode Data :  -4.73388676954341
# Batch 430 Q-Learning Episode Data :  -4.952954615159022
# Batch 431 Q-Learning Episode Data :  -5.026250831222165
# Batch 432 Q-Learning Episode Data :  -4.7191814873138265
# Batch 433 Q-Learning Episode Data :  -4.781665155831298
# Batch 434 Q-Learning Episode Data :  -4.932545310174895
# Batch 435 Q-Learning Episode Data :  -5.542900643460824
# Batch 436 Q-Learning Episode Data :  -4.757760118578956
# Batch 437 Q-Learning Episode Data :  -4.93246479033625
# Batch 438 Q-Learning Episode Data :  -4.20856883190131
# Batch 439 Q-Learning Episode Data :  -5.398752995306903
# Batch 440 Q-Learning Episode Data :  -5.275676033057254
# Batch 441 Q-Learning Episode Data :  -4.802120077771431
# Batch 442 Q-Learning Episode Data :  -5.181709427561385
# Batch 443 Q-Learning Episode Data :  -5.285549278025735
# Batch 444 Q-Learning Episode Data :  -5.430995160596931
# Batch 445 Q-Learning Episode Data :  -5.347384320764536
# Batch 446 Q-Learning Episode Data :  -5.5083017249836
# Batch 447 Q-Learning Episode Data :  -5.499719639988353
# Batch 448 Q-Learning Episode Data :  -5.057001402554866
# Batch 449 Q-Learning Episode Data :  -5.754279941041859
# Batch 450 Q-Learning Episode Data :  -5.332172779004389
# Batch 451 Q-Learning Episode Data :  -4.747925711603882
# Batch 452 Q-Learning Episode Data :  -5.1311228180916695
# Batch 453 Q-Learning Episode Data :  -5.186570101648163
# Batch 454 Q-Learning Episode Data :  -4.526395914692901
# Batch 455 Q-Learning Episode Data :  -5.6374476421719955
# Batch 456 Q-Learning Episode Data :  -5.264581671034678
# Batch 457 Q-Learning Episode Data :  -5.153879596379751
# Batch 458 Q-Learning Episode Data :  -4.928141577709231
# Batch 459 Q-Learning Episode Data :  -5.226495867076688
# Batch 460 Q-Learning Episode Data :  -4.653506745114655
# Batch 461 Q-Learning Episode Data :  -5.177342669099652
# Batch 462 Q-Learning Episode Data :  -5.310452747757026
# Batch 463 Q-Learning Episode Data :  -5.366380663045464
# Batch 464 Q-Learning Episode Data :  -5.122954159235851
# Batch 465 Q-Learning Episode Data :  -4.515171882724237
# Batch 466 Q-Learning Episode Data :  -4.656614860500549
# Batch 467 Q-Learning Episode Data :  -4.8760767893538945
# Batch 468 Q-Learning Episode Data :  -4.673812576467398
# Batch 469 Q-Learning Episode Data :  -5.298748143706765
# Batch 470 Q-Learning Episode Data :  -5.271224890234288
# Batch 471 Q-Learning Episode Data :  -4.746057041130976
# Batch 472 Q-Learning Episode Data :  -4.628794594995167
# Batch 473 Q-Learning Episode Data :  -4.743890174165466
# Batch 474 Q-Learning Episode Data :  -5.395938523852603
# Batch 475 Q-Learning Episode Data :  -5.081000899968528
# Batch 476 Q-Learning Episode Data :  -4.69091923186942
# Batch 477 Q-Learning Episode Data :  -5.185333949776427
# Batch 478 Q-Learning Episode Data :  -4.653904588763412
# Batch 479 Q-Learning Episode Data :  -5.551610336945532
# Batch 480 Q-Learning Episode Data :  -5.482986912986582
# Batch 481 Q-Learning Episode Data :  -4.81503485602949
# Batch 482 Q-Learning Episode Data :  -4.111267819523436
# Batch 483 Q-Learning Episode Data :  -4.958626661126426
# Batch 484 Q-Learning Episode Data :  -5.0603557050844925
# Batch 485 Q-Learning Episode Data :  -4.836829587735751
# Batch 486 Q-Learning Episode Data :  -5.5274585161317225
# Batch 487 Q-Learning Episode Data :  -4.888403659307188
# Batch 488 Q-Learning Episode Data :  -5.388575415195695
# Batch 489 Q-Learning Episode Data :  -4.9647108784819665
# Batch 490 Q-Learning Episode Data :  -4.682998628705068
# Batch 491 Q-Learning Episode Data :  -5.129492244874743
# Batch 492 Q-Learning Episode Data :  -4.122491543002373
# Batch 493 Q-Learning Episode Data :  -5.328055990226772
# Batch 494 Q-Learning Episode Data :  -5.515888108202087
# Batch 495 Q-Learning Episode Data :  -4.966742900206031
# Batch 496 Q-Learning Episode Data :  -5.590346468606529
# Batch 497 Q-Learning Episode Data :  -5.140941847942264
# Batch 498 Q-Learning Episode Data :  -5.172189059436419
# Batch 499 Q-Learning Episode Data :  -4.53768995316343
# Batch 500 Q-Learning Episode Data :  -4.480798702081133
# Batch 501 Q-Learning Episode Data :  -5.641877667079138
# Batch 502 Q-Learning Episode Data :  -5.611166046627465
# Batch 503 Q-Learning Episode Data :  -4.343253836465108
# Batch 504 Q-Learning Episode Data :  -5.407032922080805
# Batch 505 Q-Learning Episode Data :  -4.870727366155865
# Batch 506 Q-Learning Episode Data :  -5.18657029427405
# Batch 507 Q-Learning Episode Data :  -4.1391603233330665
# Batch 508 Q-Learning Episode Data :  -4.314072033414993
# Batch 509 Q-Learning Episode Data :  -4.657584392245014
# Batch 510 Q-Learning Episode Data :  -4.5263534236617895
# Batch 511 Q-Learning Episode Data :  -5.384450217441079
# Batch 512 Q-Learning Episode Data :  -4.732493883870748
# Batch 513 Q-Learning Episode Data :  -5.4106043964858745
# Batch 514 Q-Learning Episode Data :  -5.414079011477267
# Batch 515 Q-Learning Episode Data :  -5.614933139959676
# Batch 516 Q-Learning Episode Data :  -4.206119164456975
# Batch 517 Q-Learning Episode Data :  -5.010782559264331
# Batch 518 Q-Learning Episode Data :  -5.183655099410919
# Batch 519 Q-Learning Episode Data :  -5.428253187841316
# Batch 520 Q-Learning Episode Data :  -4.880345093069573
# Batch 521 Q-Learning Episode Data :  -5.541910501494697
# Batch 522 Q-Learning Episode Data :  -4.5679042670790055
# Batch 523 Q-Learning Episode Data :  -6.1896947842189185
# Batch 524 Q-Learning Episode Data :  -5.461943888544853
# Batch 525 Q-Learning Episode Data :  -4.917937605048273
# Batch 526 Q-Learning Episode Data :  -5.330516786503069
# Batch 527 Q-Learning Episode Data :  -5.320723759122549
# Batch 528 Q-Learning Episode Data :  -4.91886125405106
# Batch 529 Q-Learning Episode Data :  -5.849054178666561
# Batch 530 Q-Learning Episode Data :  -5.227081784001308
# Batch 531 Q-Learning Episode Data :  -5.012908589525724
# Batch 532 Q-Learning Episode Data :  -5.182419419372381
# Batch 533 Q-Learning Episode Data :  -4.728618732996673
# Batch 534 Q-Learning Episode Data :  -5.1670869858377495
# Batch 535 Q-Learning Episode Data :  -5.379211884998193
# Batch 536 Q-Learning Episode Data :  -5.4250656998086795
# Batch 537 Q-Learning Episode Data :  -5.104397738453744
# Batch 538 Q-Learning Episode Data :  -5.814503166627726
# Batch 539 Q-Learning Episode Data :  -4.99760302460167
# Batch 540 Q-Learning Episode Data :  -5.31548346650201
# Batch 541 Q-Learning Episode Data :  -4.560960281836993
# Batch 542 Q-Learning Episode Data :  -5.238879704943643
# Batch 543 Q-Learning Episode Data :  -5.775590756742137
# Batch 544 Q-Learning Episode Data :  -4.570852454974473
# Batch 545 Q-Learning Episode Data :  -4.341138676941815
# Batch 546 Q-Learning Episode Data :  -3.5953614172672883
# Batch 547 Q-Learning Episode Data :  -4.560382740921269
# Batch 548 Q-Learning Episode Data :  -4.933187339518293
# Batch 549 Q-Learning Episode Data :  -4.669680907123156
# Batch 550 Q-Learning Episode Data :  -4.558964381143463
# Batch 551 Q-Learning Episode Data :  -4.4129359394558865
# Batch 552 Q-Learning Episode Data :  -5.694326317855861
# Batch 553 Q-Learning Episode Data :  -5.273113721265456
# Batch 554 Q-Learning Episode Data :  -5.311981656692233
# Batch 555 Q-Learning Episode Data :  -5.233371112753185
# Batch 556 Q-Learning Episode Data :  -4.900974865822932
# Batch 557 Q-Learning Episode Data :  -4.804918059563547
# Batch 558 Q-Learning Episode Data :  -4.907762971549747
# Batch 559 Q-Learning Episode Data :  -5.156890472389387
# Batch 560 Q-Learning Episode Data :  -5.470772131242886
# Batch 561 Q-Learning Episode Data :  -6.1047838105774295
# Batch 562 Q-Learning Episode Data :  -5.456787988280917
# Batch 563 Q-Learning Episode Data :  -5.322332475570109
# Batch 564 Q-Learning Episode Data :  -4.991762461093478
# Batch 565 Q-Learning Episode Data :  -4.8580943936640235
# Batch 566 Q-Learning Episode Data :  -5.2477512864985965
# Batch 567 Q-Learning Episode Data :  -5.744578527279995
# Batch 568 Q-Learning Episode Data :  -5.260351374158743
# Batch 569 Q-Learning Episode Data :  -4.042834178185422
# Batch 570 Q-Learning Episode Data :  -4.061763857877594
# Batch 571 Q-Learning Episode Data :  -5.4952437395040254
# Batch 572 Q-Learning Episode Data :  -4.8607827487416895
# Batch 573 Q-Learning Episode Data :  -5.420964107577096
# Batch 574 Q-Learning Episode Data :  -5.07712417710278
# Batch 575 Q-Learning Episode Data :  -5.290488445925514
# Batch 576 Q-Learning Episode Data :  -4.875464385109041
# Batch 577 Q-Learning Episode Data :  -4.6943603573374215
# Batch 578 Q-Learning Episode Data :  -4.517692010532513
# Batch 579 Q-Learning Episode Data :  -5.784262972844023
# Batch 580 Q-Learning Episode Data :  -4.939690784700211
# Batch 581 Q-Learning Episode Data :  -4.8876383663357785
# Batch 582 Q-Learning Episode Data :  -5.467073507889467
# Batch 583 Q-Learning Episode Data :  -4.59409868079539
# Batch 584 Q-Learning Episode Data :  -5.2013528163274
# Batch 585 Q-Learning Episode Data :  -4.608166004046108
# Batch 586 Q-Learning Episode Data :  -4.4534956809249175
# Batch 587 Q-Learning Episode Data :  -5.0182956385487145
# Batch 588 Q-Learning Episode Data :  -4.9739348968701
# Batch 589 Q-Learning Episode Data :  -4.332406933833
# Batch 590 Q-Learning Episode Data :  -5.9650017112424605
# Batch 591 Q-Learning Episode Data :  -5.524819484139587
# Batch 592 Q-Learning Episode Data :  -5.030558597159148
# Batch 593 Q-Learning Episode Data :  -4.258629507960506
# Batch 594 Q-Learning Episode Data :  -4.392597271958296
# Batch 595 Q-Learning Episode Data :  -5.172781509601648
# Batch 596 Q-Learning Episode Data :  -4.375580956709452
# Batch 597 Q-Learning Episode Data :  -5.499586083458959
# Batch 598 Q-Learning Episode Data :  -5.435183261937883
# Batch 599 Q-Learning Episode Data :  -4.617862884792603
# Batch 600 Q-Learning Episode Data :  -5.118984109082828
# Batch 601 Q-Learning Episode Data :  -4.9384440381160895
# Batch 602 Q-Learning Episode Data :  -4.7747143319545735
# Batch 603 Q-Learning Episode Data :  -4.678016220812046
# Batch 604 Q-Learning Episode Data :  -5.392543406627257
# Batch 605 Q-Learning Episode Data :  -5.312959292373895
# Batch 606 Q-Learning Episode Data :  -5.274674433028613
# Batch 607 Q-Learning Episode Data :  -5.084477533329238
# Batch 608 Q-Learning Episode Data :  -6.094781494258536
# Batch 609 Q-Learning Episode Data :  -5.718624993725616
# Batch 610 Q-Learning Episode Data :  -5.1381547415630475
# Batch 611 Q-Learning Episode Data :  -5.3311715178919705
# Batch 612 Q-Learning Episode Data :  -4.716279963032411
# Batch 613 Q-Learning Episode Data :  -5.060561908629905
# Batch 614 Q-Learning Episode Data :  -4.994926622040034
# Batch 615 Q-Learning Episode Data :  -4.229515305050796
# Batch 616 Q-Learning Episode Data :  -3.9955684024214677
# Batch 617 Q-Learning Episode Data :  -5.060505844155971
# Batch 618 Q-Learning Episode Data :  -4.885266997908162
# Batch 619 Q-Learning Episode Data :  -4.8420280306181676
# Batch 620 Q-Learning Episode Data :  -4.967767373416439
# Batch 621 Q-Learning Episode Data :  -4.9756155127012915
# Batch 622 Q-Learning Episode Data :  -5.326599703897223
# Batch 623 Q-Learning Episode Data :  -4.827493000432015
# Batch 624 Q-Learning Episode Data :  -5.383708839586136
# Batch 625 Q-Learning Episode Data :  -5.11043104393604
# Batch 626 Q-Learning Episode Data :  -4.951246700348907
# Batch 627 Q-Learning Episode Data :  -4.8423300297241045
# Batch 628 Q-Learning Episode Data :  -4.194453077390851
# Batch 629 Q-Learning Episode Data :  -4.356517289854372
# Batch 630 Q-Learning Episode Data :  -4.426231817748088
# Batch 631 Q-Learning Episode Data :  -5.159390399167801
# Batch 632 Q-Learning Episode Data :  -5.458836298585266
# Batch 633 Q-Learning Episode Data :  -5.321838166066286
# Batch 634 Q-Learning Episode Data :  -4.645928239826766
# Batch 635 Q-Learning Episode Data :  -4.900393725767878
# Batch 636 Q-Learning Episode Data :  -4.9253994664289005
# Batch 637 Q-Learning Episode Data :  -5.287007923162614
# Batch 638 Q-Learning Episode Data :  -4.777258229336526
# Batch 639 Q-Learning Episode Data :  -4.860486807167331
# Batch 640 Q-Learning Episode Data :  -5.505702203457046
# Batch 641 Q-Learning Episode Data :  -4.537246174590892
# Batch 642 Q-Learning Episode Data :  -4.070914289624024
# Batch 643 Q-Learning Episode Data :  -5.137970176554226
# Batch 644 Q-Learning Episode Data :  -5.0380229867666255
# Batch 645 Q-Learning Episode Data :  -4.662093649239414
# Batch 646 Q-Learning Episode Data :  -5.05999530038566
# Batch 647 Q-Learning Episode Data :  -4.93923883973002
# Batch 648 Q-Learning Episode Data :  -4.941608020831061
# Batch 649 Q-Learning Episode Data :  -4.635258261464474
# Batch 650 Q-Learning Episode Data :  -5.092548886804211
# Batch 651 Q-Learning Episode Data :  -4.3316351098414545
# Batch 652 Q-Learning Episode Data :  -6.001539138863968
# Batch 653 Q-Learning Episode Data :  -5.0113090537575635
# Batch 654 Q-Learning Episode Data :  -4.9045647160056305
# Batch 655 Q-Learning Episode Data :  -5.386466694352093
# Batch 656 Q-Learning Episode Data :  -5.272281919382607
# Batch 657 Q-Learning Episode Data :  -4.632404497836536
# Batch 658 Q-Learning Episode Data :  -4.516804861465755
# Batch 659 Q-Learning Episode Data :  -5.1693750099163385
# Batch 660 Q-Learning Episode Data :  -4.593858321269236
# Batch 661 Q-Learning Episode Data :  -4.737652847555174
# Batch 662 Q-Learning Episode Data :  -4.6580326936646035
# Batch 663 Q-Learning Episode Data :  -5.3534206032217275
# Batch 664 Q-Learning Episode Data :  -5.897072160879903
# Batch 665 Q-Learning Episode Data :  -5.456916459586241
# Batch 666 Q-Learning Episode Data :  -5.339755433822543
# Batch 667 Q-Learning Episode Data :  -4.948616229282182
# Batch 668 Q-Learning Episode Data :  -4.504689673467253
# Batch 669 Q-Learning Episode Data :  -5.0097515570038516
# Batch 670 Q-Learning Episode Data :  -5.234221066572055
# Batch 671 Q-Learning Episode Data :  -5.560705128303741
# Batch 672 Q-Learning Episode Data :  -5.407983933831767
# Batch 673 Q-Learning Episode Data :  -5.3637791626900295
# Batch 674 Q-Learning Episode Data :  -5.1019401226137955
# Batch 675 Q-Learning Episode Data :  -4.40813927354849
# Batch 676 Q-Learning Episode Data :  -5.009841336279281
# Batch 677 Q-Learning Episode Data :  -5.311419135788367
# Batch 678 Q-Learning Episode Data :  -5.116743239819833
# Batch 679 Q-Learning Episode Data :  -5.306950366797373
# Batch 680 Q-Learning Episode Data :  -4.894772664607205
# Batch 681 Q-Learning Episode Data :  -5.539491432242593
# Batch 682 Q-Learning Episode Data :  -4.9226850854691495
# Batch 683 Q-Learning Episode Data :  -5.516624565245399
# Batch 684 Q-Learning Episode Data :  -5.485530082263182
# Batch 685 Q-Learning Episode Data :  -5.543658750287733
# Batch 686 Q-Learning Episode Data :  -5.191679791886838
# Batch 687 Q-Learning Episode Data :  -5.366616488077422
# Batch 688 Q-Learning Episode Data :  -4.67784079112664
# Batch 689 Q-Learning Episode Data :  -4.621684582063069
# Batch 690 Q-Learning Episode Data :  -5.48576629804008
# Batch 691 Q-Learning Episode Data :  -4.680919644026774
# Batch 692 Q-Learning Episode Data :  -4.337530421770118
# Batch 693 Q-Learning Episode Data :  -4.8180746204362235
# Batch 694 Q-Learning Episode Data :  -5.307728821270098
# Batch 695 Q-Learning Episode Data :  -5.374256665028266
# Batch 696 Q-Learning Episode Data :  -4.658702024626839
# Batch 697 Q-Learning Episode Data :  -5.082099919847809
# Batch 698 Q-Learning Episode Data :  -5.219708608638997
# Batch 699 Q-Learning Episode Data :  -5.527531448487056
# Batch 700 Q-Learning Episode Data :  -5.626468559620646
# Batch 701 Q-Learning Episode Data :  -4.987093341990462
# Batch 702 Q-Learning Episode Data :  -4.9618054783149175
# Batch 703 Q-Learning Episode Data :  -4.569213772320633
# Batch 704 Q-Learning Episode Data :  -5.16090137993994
# Batch 705 Q-Learning Episode Data :  -5.14777714611704
# Batch 706 Q-Learning Episode Data :  -5.203165351751576
# Batch 707 Q-Learning Episode Data :  -5.230708448449153
# Batch 708 Q-Learning Episode Data :  -5.901693841716401
# Batch 709 Q-Learning Episode Data :  -4.794608724103493
# Batch 710 Q-Learning Episode Data :  -4.601634361774177
# Batch 711 Q-Learning Episode Data :  -5.145339472418006
# Batch 712 Q-Learning Episode Data :  -5.439070093494561
# Batch 713 Q-Learning Episode Data :  -5.164494766429692
# Batch 714 Q-Learning Episode Data :  -4.872249712300971
# Batch 715 Q-Learning Episode Data :  -4.82667254167331
# Batch 716 Q-Learning Episode Data :  -4.766705951236324
# Batch 717 Q-Learning Episode Data :  -4.827368042224276
# Batch 718 Q-Learning Episode Data :  -4.807613468165112
# Batch 719 Q-Learning Episode Data :  -4.435222235348534
# Batch 720 Q-Learning Episode Data :  -4.608862945315538
# Batch 721 Q-Learning Episode Data :  -4.96923973178368
# Batch 722 Q-Learning Episode Data :  -4.92559847099934
# Batch 723 Q-Learning Episode Data :  -4.342385531576421
# Batch 724 Q-Learning Episode Data :  -4.555136671817405
# Batch 725 Q-Learning Episode Data :  -3.838219786764191
# Batch 726 Q-Learning Episode Data :  -4.723435476248892
# Batch 727 Q-Learning Episode Data :  -4.508315261236
# Batch 728 Q-Learning Episode Data :  -5.048818836793748
# Batch 729 Q-Learning Episode Data :  -4.555812819868191
# Batch 730 Q-Learning Episode Data :  -5.092112201426945
# Batch 731 Q-Learning Episode Data :  -4.999533571084319
# Batch 732 Q-Learning Episode Data :  -5.099493056634396
# Batch 733 Q-Learning Episode Data :  -4.610020368738756
# Batch 734 Q-Learning Episode Data :  -5.053933894549189
# Batch 735 Q-Learning Episode Data :  -5.425118607600532
# Batch 736 Q-Learning Episode Data :  -5.394870103346774
# Batch 737 Q-Learning Episode Data :  -5.08763672541309
# Batch 738 Q-Learning Episode Data :  -5.30076819777489
# Batch 739 Q-Learning Episode Data :  -5.113384980414648
# Batch 740 Q-Learning Episode Data :  -5.365135153880454
# Batch 741 Q-Learning Episode Data :  -5.569252578050331
# Batch 742 Q-Learning Episode Data :  -4.515569638844881
# Batch 743 Q-Learning Episode Data :  -5.205094969607005
# Batch 744 Q-Learning Episode Data :  -5.419404126645339
# Batch 745 Q-Learning Episode Data :  -4.698823864878703
# Batch 746 Q-Learning Episode Data :  -5.109516548637578
# Batch 747 Q-Learning Episode Data :  -5.338882822239375
# Batch 748 Q-Learning Episode Data :  -4.848169613356517
# Batch 749 Q-Learning Episode Data :  -4.506602454374894
# Batch 750 Q-Learning Episode Data :  -5.026237556589034
# Batch 751 Q-Learning Episode Data :  -5.808445652100492
# Batch 752 Q-Learning Episode Data :  -5.415492508069093
# Batch 753 Q-Learning Episode Data :  -5.173636828691955
# Batch 754 Q-Learning Episode Data :  -4.296391196877746
# Batch 755 Q-Learning Episode Data :  -4.593043894349013
# Batch 756 Q-Learning Episode Data :  -4.984842757792189
# Batch 757 Q-Learning Episode Data :  -5.283419531998193
# Batch 758 Q-Learning Episode Data :  -4.979135413126326
# Batch 759 Q-Learning Episode Data :  -5.303466614544107
# Batch 760 Q-Learning Episode Data :  -5.165812315619006
# Batch 761 Q-Learning Episode Data :  -5.439852793356553
# Batch 762 Q-Learning Episode Data :  -4.779508787297988
# Batch 763 Q-Learning Episode Data :  -5.505226719756109
# Batch 764 Q-Learning Episode Data :  -5.345276644171241
# Batch 765 Q-Learning Episode Data :  -5.316973942730785
# Batch 766 Q-Learning Episode Data :  -4.826311982230928
# Batch 767 Q-Learning Episode Data :  -5.18959427225213
# Batch 768 Q-Learning Episode Data :  -5.83921686397412
# Batch 769 Q-Learning Episode Data :  -4.958259890125836
# Batch 770 Q-Learning Episode Data :  -4.324946200527741
# Batch 771 Q-Learning Episode Data :  -4.841984488101398
# Batch 772 Q-Learning Episode Data :  -5.203537771966693
# Batch 773 Q-Learning Episode Data :  -5.57141786999539
# Batch 774 Q-Learning Episode Data :  -5.079824343378716
# Batch 775 Q-Learning Episode Data :  -5.134064487656257
# Batch 776 Q-Learning Episode Data :  -4.828293807752155
# Batch 777 Q-Learning Episode Data :  -4.834617766024729
# Batch 778 Q-Learning Episode Data :  -5.316661440319547
# Batch 779 Q-Learning Episode Data :  -5.884148006998604
# Batch 780 Q-Learning Episode Data :  -4.799550725353204
# Batch 781 Q-Learning Episode Data :  -5.6638593878727646
# Batch 782 Q-Learning Episode Data :  -5.079553672659061
# Batch 783 Q-Learning Episode Data :  -5.040902422185178
# Batch 784 Q-Learning Episode Data :  -5.828659017115414
# Batch 785 Q-Learning Episode Data :  -5.166992811347335
# Batch 786 Q-Learning Episode Data :  -5.188266872779734
# Batch 787 Q-Learning Episode Data :  -4.909446734050034
# Batch 788 Q-Learning Episode Data :  -4.297836950646516
# Batch 789 Q-Learning Episode Data :  -4.64920700138508
# Batch 790 Q-Learning Episode Data :  -5.774683775948211
# Batch 791 Q-Learning Episode Data :  -4.793042569188099
# Batch 792 Q-Learning Episode Data :  -5.234382685045928
# Batch 793 Q-Learning Episode Data :  -4.927473467089364
# Batch 794 Q-Learning Episode Data :  -5.24716569052703
# Batch 795 Q-Learning Episode Data :  -4.5930697093939505
# Batch 796 Q-Learning Episode Data :  -5.100461267718858
# Batch 797 Q-Learning Episode Data :  -4.551978010488382
# Batch 798 Q-Learning Episode Data :  -4.910878091707396
# Batch 799 Q-Learning Episode Data :  -5.714069757952563
# Batch 800 Q-Learning Episode Data :  -4.649129172259933
# Batch 801 Q-Learning Episode Data :  -5.4579066104317
# Batch 802 Q-Learning Episode Data :  -4.777515688622612
# Batch 803 Q-Learning Episode Data :  -4.918774558050678
# Batch 804 Q-Learning Episode Data :  -4.800275636428014
# Batch 805 Q-Learning Episode Data :  -5.542954972556485
# Batch 806 Q-Learning Episode Data :  -5.095177092155198
# Batch 807 Q-Learning Episode Data :  -5.256609188052031
# Batch 808 Q-Learning Episode Data :  -4.9249365035085235
# Batch 809 Q-Learning Episode Data :  -5.062409580297592
# Batch 810 Q-Learning Episode Data :  -4.650350857438772
# Batch 811 Q-Learning Episode Data :  -4.6749721592802596
# Batch 812 Q-Learning Episode Data :  -5.397033528519313
# Batch 813 Q-Learning Episode Data :  -5.573582982675786
# Batch 814 Q-Learning Episode Data :  -5.557020779517661
# Batch 815 Q-Learning Episode Data :  -4.85158966536573
# Batch 816 Q-Learning Episode Data :  -4.756308839195166
# Batch 817 Q-Learning Episode Data :  -4.440695705781045
# Batch 818 Q-Learning Episode Data :  -4.842961426196388
# Batch 819 Q-Learning Episode Data :  -5.60055396255791
# Batch 820 Q-Learning Episode Data :  -5.426143971124987
# Batch 821 Q-Learning Episode Data :  -6.011565384953302
# Batch 822 Q-Learning Episode Data :  -5.148260467578502
# Batch 823 Q-Learning Episode Data :  -5.563900169953653
# Batch 824 Q-Learning Episode Data :  -5.158112766538855
# Batch 825 Q-Learning Episode Data :  -4.558004828756614
# Batch 826 Q-Learning Episode Data :  -5.356290074377949
# Batch 827 Q-Learning Episode Data :  -4.620318452075697
# Batch 828 Q-Learning Episode Data :  -5.112491838047986
# Batch 829 Q-Learning Episode Data :  -4.909490009549619
# Batch 830 Q-Learning Episode Data :  -4.92183129410947
# Batch 831 Q-Learning Episode Data :  -4.613697970613515
# Batch 832 Q-Learning Episode Data :  -5.132727844605602
# Batch 833 Q-Learning Episode Data :  -3.983434396691266
# Batch 834 Q-Learning Episode Data :  -4.92916922168015
# Batch 835 Q-Learning Episode Data :  -4.916288664435961
# Batch 836 Q-Learning Episode Data :  -5.038643274743122
# Batch 837 Q-Learning Episode Data :  -4.925596739664991
# Batch 838 Q-Learning Episode Data :  -4.729127757120713
# Batch 839 Q-Learning Episode Data :  -5.006321230482936
# Batch 840 Q-Learning Episode Data :  -4.0613125595939366
# Batch 841 Q-Learning Episode Data :  -5.411276447111871
# Batch 842 Q-Learning Episode Data :  -4.660684275007864
# Batch 843 Q-Learning Episode Data :  -4.988473599519608
# Batch 844 Q-Learning Episode Data :  -4.6542185552992885
# Batch 845 Q-Learning Episode Data :  -4.450587223826615
# Batch 846 Q-Learning Episode Data :  -4.833692548293013
# Batch 847 Q-Learning Episode Data :  -5.103333622534241
# Batch 848 Q-Learning Episode Data :  -5.057529987235112
# Batch 849 Q-Learning Episode Data :  -5.283633288328681
# Batch 850 Q-Learning Episode Data :  -5.480522466849132
# Batch 851 Q-Learning Episode Data :  -5.0047264935947515
# Batch 852 Q-Learning Episode Data :  -5.261892042321423
# Batch 853 Q-Learning Episode Data :  -4.979767733228361
# Batch 854 Q-Learning Episode Data :  -4.916889829522501
# Batch 855 Q-Learning Episode Data :  -4.871143368145871
# Batch 856 Q-Learning Episode Data :  -4.357607427955084
# Batch 857 Q-Learning Episode Data :  -4.978698163012798
# Batch 858 Q-Learning Episode Data :  -4.941538345976671
# Batch 859 Q-Learning Episode Data :  -5.668670818580633
# Batch 860 Q-Learning Episode Data :  -5.016282459570506
# Batch 861 Q-Learning Episode Data :  -5.52697033199086
# Batch 862 Q-Learning Episode Data :  -5.3181728752416015
# Batch 863 Q-Learning Episode Data :  -5.46572474923984
# Batch 864 Q-Learning Episode Data :  -5.163112566438025
# Batch 865 Q-Learning Episode Data :  -5.190413937566251
# Batch 866 Q-Learning Episode Data :  -5.024797687493504
# Batch 867 Q-Learning Episode Data :  -6.066162579649682
# Batch 868 Q-Learning Episode Data :  -5.068135198112573
# Batch 869 Q-Learning Episode Data :  -4.531490837240966
# Batch 870 Q-Learning Episode Data :  -5.17749716982569
# Batch 871 Q-Learning Episode Data :  -5.266319532570045
# Batch 872 Q-Learning Episode Data :  -5.029598098785498
# Batch 873 Q-Learning Episode Data :  -4.819807805445248
# Batch 874 Q-Learning Episode Data :  -5.347980474260703
# Batch 875 Q-Learning Episode Data :  -4.4223741714263305
# Batch 876 Q-Learning Episode Data :  -4.849397495049064
# Batch 877 Q-Learning Episode Data :  -5.068997738609117
# Batch 878 Q-Learning Episode Data :  -5.534005891592048
# Batch 879 Q-Learning Episode Data :  -4.5779992790238335
# Batch 880 Q-Learning Episode Data :  -5.084106905526415
# Batch 881 Q-Learning Episode Data :  -4.590411041048856
# Batch 882 Q-Learning Episode Data :  -4.113784754680538
# Batch 883 Q-Learning Episode Data :  -5.512525695923858
# Batch 884 Q-Learning Episode Data :  -5.40568760078005
# Batch 885 Q-Learning Episode Data :  -4.676583495124945
# Batch 886 Q-Learning Episode Data :  -4.6838098315071015
# Batch 887 Q-Learning Episode Data :  -5.472082969439904
# Batch 888 Q-Learning Episode Data :  -5.137882238960103
# Batch 889 Q-Learning Episode Data :  -5.184614270782847
# Batch 890 Q-Learning Episode Data :  -5.389141237512467
# Batch 891 Q-Learning Episode Data :  -4.4495104738268045
# Batch 892 Q-Learning Episode Data :  -5.681422527361214
# Batch 893 Q-Learning Episode Data :  -4.897018760521821
# Batch 894 Q-Learning Episode Data :  -5.409462289805721
# Batch 895 Q-Learning Episode Data :  -5.76160147057936
# Batch 896 Q-Learning Episode Data :  -4.581548467904718
# Batch 897 Q-Learning Episode Data :  -4.441639878094563
# Batch 898 Q-Learning Episode Data :  -4.752375766667631
# Batch 899 Q-Learning Episode Data :  -4.3221264139189906
# Batch 900 Q-Learning Episode Data :  -4.973315989218105
# Batch 901 Q-Learning Episode Data :  -4.318846159187205
# Batch 902 Q-Learning Episode Data :  -4.864926595003594
# Batch 903 Q-Learning Episode Data :  -5.555185354785898
# Batch 904 Q-Learning Episode Data :  -5.554207903411928
# Batch 905 Q-Learning Episode Data :  -5.229950330006059
# Batch 906 Q-Learning Episode Data :  -5.069884609615016
# Batch 907 Q-Learning Episode Data :  -5.054490556689103
# Batch 908 Q-Learning Episode Data :  -4.822006649178849
# Batch 909 Q-Learning Episode Data :  -6.501353830437319
# Batch 910 Q-Learning Episode Data :  -5.328906406943573
# Batch 911 Q-Learning Episode Data :  -4.871141162404267
# Batch 912 Q-Learning Episode Data :  -4.444204631177128
# Batch 913 Q-Learning Episode Data :  -5.24203723285574
# Batch 914 Q-Learning Episode Data :  -5.113220997019017
# Batch 915 Q-Learning Episode Data :  -5.245999595268289
# Batch 916 Q-Learning Episode Data :  -4.7265213584531995
# Batch 917 Q-Learning Episode Data :  -4.195381904564985
# Batch 918 Q-Learning Episode Data :  -4.8953423379823615
# Batch 919 Q-Learning Episode Data :  -4.917387854092849
# Batch 920 Q-Learning Episode Data :  -5.600350205390036
# Batch 921 Q-Learning Episode Data :  -5.3074489045179964
# Batch 922 Q-Learning Episode Data :  -5.53615305428126
# Batch 923 Q-Learning Episode Data :  -5.466507877714928
# Batch 924 Q-Learning Episode Data :  -4.749772843985848
# Batch 925 Q-Learning Episode Data :  -5.273036947295534
# Batch 926 Q-Learning Episode Data :  -5.070165918153101
# Batch 927 Q-Learning Episode Data :  -5.021768253344541
# Batch 928 Q-Learning Episode Data :  -4.318182999716979
# Batch 929 Q-Learning Episode Data :  -4.503399717442962
# Batch 930 Q-Learning Episode Data :  -5.357907955195832
# Batch 931 Q-Learning Episode Data :  -4.69436831485782
# Batch 932 Q-Learning Episode Data :  -5.179490192465814
# Batch 933 Q-Learning Episode Data :  -5.426295677675361
# Batch 934 Q-Learning Episode Data :  -5.837216905484066
# Batch 935 Q-Learning Episode Data :  -4.931960638477643
# Batch 936 Q-Learning Episode Data :  -4.783951686334258
# Batch 937 Q-Learning Episode Data :  -4.98469983090164
# Batch 938 Q-Learning Episode Data :  -5.40016145925332
# Batch 939 Q-Learning Episode Data :  -5.178387901641007
# Batch 940 Q-Learning Episode Data :  -4.85620580008702
# Batch 941 Q-Learning Episode Data :  -4.940553703674688
# Batch 942 Q-Learning Episode Data :  -4.913588007501243
# Batch 943 Q-Learning Episode Data :  -4.40550037968053
# Batch 944 Q-Learning Episode Data :  -4.805410724056899
# Batch 945 Q-Learning Episode Data :  -4.772198965389052
# Batch 946 Q-Learning Episode Data :  -5.325677917262576
# Batch 947 Q-Learning Episode Data :  -4.9312237420765195
# Batch 948 Q-Learning Episode Data :  -5.3342147511055265
# Batch 949 Q-Learning Episode Data :  -4.917202171749118
# Batch 950 Q-Learning Episode Data :  -5.181218721240302
# Batch 951 Q-Learning Episode Data :  -4.272521514379318
# Batch 952 Q-Learning Episode Data :  -4.653033294365648
# Batch 953 Q-Learning Episode Data :  -5.063208931301733
# Batch 954 Q-Learning Episode Data :  -5.553467763032572
# Batch 955 Q-Learning Episode Data :  -5.227524503412124
# Batch 956 Q-Learning Episode Data :  -5.143691360855146
# Batch 957 Q-Learning Episode Data :  -4.936156461770454
# Batch 958 Q-Learning Episode Data :  -4.938571401604451
# Batch 959 Q-Learning Episode Data :  -4.373262777651363
# Batch 960 Q-Learning Episode Data :  -5.0037705558486625
# Batch 961 Q-Learning Episode Data :  -5.501275803686352
# Batch 962 Q-Learning Episode Data :  -5.053589093080873
# Batch 963 Q-Learning Episode Data :  -5.789713878857053
# Batch 964 Q-Learning Episode Data :  -4.617090896792919
# Batch 965 Q-Learning Episode Data :  -5.156654438838196
# Batch 966 Q-Learning Episode Data :  -5.038336087122027
# Batch 967 Q-Learning Episode Data :  -5.136210486236286
# Batch 968 Q-Learning Episode Data :  -4.96600836846063
# Batch 969 Q-Learning Episode Data :  -5.782791343819044
# Batch 970 Q-Learning Episode Data :  -5.230057385805412
# Batch 971 Q-Learning Episode Data :  -4.792101007444642
# Batch 972 Q-Learning Episode Data :  -5.652213636321237
# Batch 973 Q-Learning Episode Data :  -4.782745588503927
# Batch 974 Q-Learning Episode Data :  -5.477162587116434
# Batch 975 Q-Learning Episode Data :  -5.038693558434902
# Batch 976 Q-Learning Episode Data :  -5.440959089839556
# Batch 977 Q-Learning Episode Data :  -5.365054203941415
# Batch 978 Q-Learning Episode Data :  -4.656590903122497
# Batch 979 Q-Learning Episode Data :  -4.761629688233784
# Batch 980 Q-Learning Episode Data :  -5.656312842370048
# Batch 981 Q-Learning Episode Data :  -4.8906449005178425
# Batch 982 Q-Learning Episode Data :  -5.155039453469222
# Batch 983 Q-Learning Episode Data :  -5.308899965019048
# Batch 984 Q-Learning Episode Data :  -4.590927547956096
# Batch 985 Q-Learning Episode Data :  -4.848196496382667
# Batch 986 Q-Learning Episode Data :  -5.59004025779946
# Batch 987 Q-Learning Episode Data :  -4.383902364168083
# Batch 988 Q-Learning Episode Data :  -4.630173952264824
# Batch 989 Q-Learning Episode Data :  -5.2722689636599185
# Batch 990 Q-Learning Episode Data :  -5.233747152143319
# Batch 991 Q-Learning Episode Data :  -4.882051676981744
# Batch 992 Q-Learning Episode Data :  -5.0370033826125775
# Batch 993 Q-Learning Episode Data :  -4.158444712652825
# Batch 994 Q-Learning Episode Data :  -4.859061853176537
# Batch 995 Q-Learning Episode Data :  -4.78028038188713
# Batch 996 Q-Learning Episode Data :  -4.3547078176155365
# Batch 997 Q-Learning Episode Data :  -4.815719970025538
# Batch 998 Q-Learning Episode Data :  -4.485329201518856
# Batch 999 Q-Learning Episode Data :  -4.5800332939323996
# Batch 1000 Q-Learning Episode Data :  -5.256650200556522
